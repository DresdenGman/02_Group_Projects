# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Maternal & InfantProductSalesData Analysis" data-toc-modified-id="Maternal & InfantProductSalesData Analysis-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Maternal & InfantProductSalesData Analysis</a></span><ul class="toc-item"><li><span><a href="#Project Introduction" data-toc-modified-id="Project Introduction-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Project Introduction</a></span><ul class="toc-item"><li><span><a href="#Project Background" data-toc-modified-id="Project Background-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Project Background</a></span></li><li><span><a href="#analysis" data-toc-modified-id="analysis-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>analysis</a></span></li></ul></li><li><span><a href="#Data Preparation" data-toc-modified-id="Data Preparation-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data Preparation</a></span><ul class="toc-item"><li><span><a href="#importdata" data-toc-modified-id="importdata-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>importdata</a></span></li><li><span><a href="#Data Cleaning" data-toc-modified-id="Data Cleaning-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Data Cleaning</a></span></li></ul></li><li><span><a href="#Data Analysis" data-toc-modified-id="Data Analysis-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Data Analysis</a></span><ul class="toc-item"><li><span><a href="#" data-toc-modified-id="-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span></a></span><ul class="toc-item"><li><span><a href="#" data-toc-modified-id="-1.3.1.1"><span class="toc-item-num">1.3.1.1&nbsp;&nbsp;</span></a></span></li><li><span><a href="#" data-toc-modified-id="-1.3.1.2"><span class="toc-item-num">1.3.1.2&nbsp;&nbsp;</span></a></span></li><li><span><a href="#" data-toc-modified-id="-1.3.1.3"><span class="toc-item-num">1.3.1.3&nbsp;&nbsp;</span></a></span></li></ul></li><li><span><a href="#ProductSales" data-toc-modified-id="ProductSales-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>ProductSales</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Maternal & InfantProductSalesData Analysis

# %% [markdown]
# ## Project Introduction

# %% [markdown]
# ### Project Background
# Politics：2013year5month28dayindicates，13，、、、 and 5，Maternal & InfantProduct。
#
# Economy：，2015yearRevenue31195， Revenue11422。RevenueConsumption，2015yearMaternal & Infant2。
#
# Society：AnalyzeCity，hourthrough 、i.e. ShoppingConsumption；AnalyzeCityand，。
#
# Technology：4G、 and ipad、，。

# %% [markdown]
# ### analysis
# 1. Analyzedifferent time and different Sales and ， and 、。
# 2. based onpredictionAge，based oninfo(Age、Gender)predictionuserProduct。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pyecharts.charts as pyc
import pyecharts.options as opts
import warnings
from datetime import datetime
warnings.filterwarnings("ignore")
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = False
# 
fontdict = {'fontsize': 15,
            'horizontalalignment': 'center'}

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### importdata

# %%
baby = pd.read_csv("./(sample)sam_tianchi_mum_baby.csv")
trade = pd.read_csv("./(sample)sam_tianchi_mum_baby_trade_history.csv")

# %%
baby.head()
# Out:
#     user_id  birthday  gender
# 0      2757  20130311       1
# 1    415971  20121111       0
# 2   1372572  20120130       1
# 3  10339332  20110910       0
# 4  10642245  20130213       0

# %%
trade.head()
# Out:
#      user_id   auction_id    cat_id      cat1  \
# 0  786295544  41098319944  50014866  50022520
# 1  532110457  17916191097  50011993        28
# 2  249013725  21896936223  50012461  50014815
# 3  917056007  12515996043  50018831  50014815
# 4  444069173  20487688075  50013636  50008168
#
#                                             property  buy_mount       day
# 0  21458:86755362;13023209:3593274;10984217:21985...          2  20140919
# 1  21458:11399317;1628862:3251296;21475:137325;16...          1  20131011
# 2  21458:30992;1628665:92012;1628665:3233938;1628...          1  20131011
# 3  21458:15841995;21956:3494076;27000458:59723383...          2  20141023
# 4  21458:30992;13658074:3323064;1628665:3233941;1...          1  20141103

# %%
baby.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   953 non-null    int64
#  1   birthday  953 non-null    int64
#  2   gender    953 non-null    int64
# dtypes: int64(3)
# memory usage: 22.5 KB

# %%
trade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29971 entries, 0 to 29970
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     29971 non-null  int64
#  1   auction_id  29971 non-null  int64
#  2   cat_id      29971 non-null  int64
#  3   cat1        29971 non-null  int64
#  4   property    29827 non-null  object
#  5   buy_mount   29971 non-null  int64
#  6   day         29971 non-null  int64
# dtypes: int64(6), object(1)
# memory usage: 1.6+ MB

# %%
trade.buy_mount.describe()
# Out:
# count    29971.000000
# mean         2.544126
# std         63.986879
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max      10000.000000
# Name: buy_mount, dtype: float64

# %%
quantity = trade.buy_mount.value_counts().sort_index()
plt.figure(figsize=(10, 8))
sns.scatterplot(x=quantity.index, y=quantity.values, alpha=0.3)
plt.title("OrderDistribution", fontdict=fontdict)
plt.ylabel("Order", fontdict=fontdict)
plt.xlabel("", fontdict=fontdict)
plt.show()

# %% [markdown]
# ### Data Cleaning
# 1. buy_amount[1,195]Order。
# 2. viewmissing values，processing。
# 3. tradeauction_idyesattribute，item_id。
# 4. datasetpropertyyes，need to AnalyzeAnalyzeattribute，。
# 5. daydate。

# %%
# buy_mount[0,195]record
trade = trade[(trade.buy_mount >= 1) & (trade.buy_mount <= 195)]
# 
trade.rename({"auction_id": "item_id"}, axis=1, inplace=True)
# property，analysis
property = trade.property
trade.drop('property', axis=1, inplace=True)
# date
baby['birthday'] = pd.to_datetime(baby.birthday.astype('str'))
trade['day'] = pd.to_datetime(trade.day.astype('str'))

# %%
# datatime2012/7/2-2015/2/5
trade.day.describe()
# Out:
# count                   29942
# unique                    949
# top       2014-11-11 00:00:00
# freq                      454
# first     2012-07-02 00:00:00
# last      2015-02-05 00:00:00
# Name: day, dtype: object

# %%
count_cat1 = trade.cat1.nunique()
count_cat = trade.cat_id.nunique()
count_item = trade.item_id.nunique()
sales_volume = trade.buy_mount.sum()
count_user = trade.user_id.nunique()
print("Product：", count_cat1)
print("Product：", count_cat)
print("Product：", count_item)
print("：", sales_volume)
print("user", count_user)
# Out:
# Product： 6
# Product： 662
# Product： 28394
# ： 49973
# user 29915

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ###

# %%
# based on yearmonthview
# based on yearminute
year_item = trade[['item_id', 'buy_mount', 'day']].groupby(by=trade.day.dt.year)[
    'buy_mount'].sum()
# year
year_quarter_item = trade[['item_id', 'buy_mount', 'day']].groupby(by=[trade.day.dt.year, trade.day.dt.quarter])[
    'buy_mount'].sum()
# based on yearmonthminute
year_month_item = trade[['item_id', 'buy_mount', 'day']].groupby(
    by=[trade.day.dt.year, trade.day.dt.month])['buy_mount'].sum()

# %%
# year
plt.figure(figsize=(10, 5))
sns.barplot(x=year_item.index, y=year_item.values)
plt.title("year", fontdict=fontdict)
plt.xlabel("Year", fontdict=fontdict)
plt.ylabel("", fontdict=fontdict)
plt.show()

# %% [markdown]
#     2017/7-2015/2yes49973，We can see  and daysMaternal & InfantProduct，yes。

# %%
index_list = year_quarter_item.index.tolist()
index_list = ['-'.join([str(x[0]),str(x[1])]) for x in index_list]
index_list
# Out:
# ['2012-3',
#  '2012-4',
#  '2013-1',
#  '2013-2',
#  '2013-3',
#  '2013-4',
#  '2014-1',
#  '2014-2',
#  '2014-3',
#  '2014-4',
#  '2015-1']

# %%
# Sales
plt.figure(figsize=(10, 5))
sns.barplot(x=index_list, y=year_quarter_item.values)
plt.title("", fontdict=fontdict)
plt.xlabel("(year,)", fontdict=fontdict)
plt.ylabel("", fontdict=fontdict)
plt.show()

# %% [markdown]
# 1. 2015yeardata， so 2015year
# 2. yearSales。year。

# %%
# Month
x = [str(x[0])+"/"+str(x[1]) for x in year_month_item.index]
y = [int(x) for x in year_month_item.values]
p  =pyc.Bar().add_xaxis(xaxis_data=x
                    ).add_yaxis(series_name="", y_axis=y, 
                        markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(coord=[x[4], y[4]], value=y[4]), 
                        opts.MarkPointItem(coord=[x[10], y[10]], value=y[10]), 
                    opts.MarkPointItem(coord=[x[16], y[16]], value=y[16]), 
                    opts.MarkPointItem(coord=[x[22], y[22]], value=y[22]), opts.MarkPointItem(coord=[x[28], y[28]], value=y[28])])
                    ).set_series_opts(label_opts=opts.LabelOpts(is_show=False)
                ).set_global_opts(title_opts=opts.TitleOpts(title="month", subtitle="2012/7-2015/2"), toolbox_opts=opts.ToolboxOpts())
p.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="92e44049bba845db934a91571d2ed6b4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_92e44049bba845db934a91571d2ed6b4 = echarts.init(
#                     document.getElementById('92e44049bba845db934a91571d2ed6b4'), 'white', {renderer: 'canvas'});
#                 var option_92e44049bba845db934a91571d2ed6b4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %% [markdown]
# 1. 2013year and 2014year，main 1、2month。
# 2. year5month、11monthdifferent 。

# %% [markdown]
# ####
# Salesyes and ?\

# %%
def quarterData(trade: pd.DataFrame, low: tuple, high: tuple) -> list:
    """
    date,date and user
    """
    from datetime import datetime
    low = datetime.strptime(low, "%Y/%m/%d")
    high = datetime.strptime(high, "%Y/%m/%d")
    trade_low = trade[(trade.day >= datetime(low.year, low.month, low.day)) & (
        trade.day <= datetime(high.year, high.month, high.day))]
    group_low = trade_low[['buy_mount', 'day', 'user_id']].groupby(
        by=[trade_low.day.dt.month, trade_low.day.dt.day])
    mount = group_low.buy_mount.sum()
    user = group_low.user_id.nunique()

    return [mount, user]

# %%
def lineMountUser(mount, user, title):
    """
     and userdataand ，
    """
    plot = pyc.Line().add_xaxis(xaxis_data=[str(x[0])+"/"+str(x[1]) for x in mount.index]
                                ).add_yaxis(series_name="", y_axis=[int(x) for x in mount.values], markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(name='month', type_="average")])
                                            ).add_yaxis(series_name="user", y_axis=[int(x) for x in user.values], markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(name='monthuser', type_="average")])
                                                        ).set_series_opts(label_opts=opts.LabelOpts(is_show=False)
                                                                          ).set_global_opts(title_opts=opts.TitleOpts(title=title), toolbox_opts=opts.ToolboxOpts(), tooltip_opts=opts.TooltipOpts(trigger='axis')
                                                                                            ).render_notebook()
    return plot

# %%
mount_2013_1_quarter = quarterData(trade, "2013/1/1", "2013/3/31")[0]
mount_2014_1_quarter = quarterData(trade, "2014/1/1", "2014/3/31")[0]
user_2013_1_quarter = quarterData(trade, "2013/1/1", "2013/3/31")[1]
user_2014_1_quarter = quarterData(trade, "2014/1/1", "2014/3/31")[1]

# %%
lineMountUser(mount_2013_1_quarter, user_2013_1_quarter, "2013year")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f02248a2ba98410fa93bc8e5e5e8d53d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f02248a2ba98410fa93bc8e5e5e8d53d = echarts.init(
#                     document.getElementById('f02248a2ba98410fa93bc8e5e5e8d53d'), 'white', {renderer: 'canvas'});
#                 var option_f02248a2ba98410fa93bc8e5e5e8d53d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
lineMountUser(mount_2014_1_quarter, user_2014_1_quarter, "2014year")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f419a514fc7c48f7ae7e6599c64ad806" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f419a514fc7c48f7ae7e6599c64ad806 = echarts.init(
#                     document.getElementById('f419a514fc7c48f7ae7e6599c64ad806'), 'white', {renderer: 'canvas'});
#                 var option_f419a514fc7c48f7ae7e6599c64ad806 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %% [markdown]
# - 2013/2/1-2013/2/15，2013year：2013/2/9-2013/2/15
# - 2014/1/26-2014/2/4Sales，2014year：2014/1/31-2014/2/6
# > 2015yearyes2015/2/18-2015/2/24，datasettime2015/2/5， so analysis2015year
#
# may has minute，，Saleshourbasic ， and user， so can yes

# %% [markdown]
# ####
# yes1112？

# %%
mount_2012_4_quarter, user_2012_4_quarter = quarterData(
    trade, "2012/10/1", "2012/12/31")
mount_2013_4_quarter, user_2013_4_quarter = quarterData(
    trade, "2013/10/1", "2013/12/31")
mount_2014_4_quarter, user_2014_4_quarter = quarterData(
    trade, "2014/10/1", "2014/12/31")

# %%
lineMountUser(mount_2012_4_quarter, user_2012_4_quarter, "2012year")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="018a5a86562446dc8cc7a3c7d1ef605a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_018a5a86562446dc8cc7a3c7d1ef605a = echarts.init(
#                     document.getElementById('018a5a86562446dc8cc7a3c7d1ef605a'), 'white', {renderer: 'canvas'});
#                 var option_018a5a86562446dc8cc7a3c7d1ef605a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
lineMountUser(mount_2013_4_quarter, user_2013_4_quarter, "2013year")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d84cf0c7f6bc4b558037e841b0801fc8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d84cf0c7f6bc4b558037e841b0801fc8 = echarts.init(
#                     document.getElementById('d84cf0c7f6bc4b558037e841b0801fc8'), 'white', {renderer: 'canvas'});
#                 var option_d84cf0c7f6bc4b558037e841b0801fc8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
lineMountUser(mount_2014_4_quarter, user_2014_4_quarter, "2014year")
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dff62985723f493f93ce9f1ba44fb074" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dff62985723f493f93ce9f1ba44fb074 = echarts.init(
#                     document.getElementById('dff62985723f493f93ce9f1ba44fb074'), 'white', {renderer: 'canvas'});
#                 var option_dff62985723f493f93ce9f1ba44fb074 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %% [markdown]
# 1. can 2013year and 2014yearDouble 11days and Sales。
# 2. yearDouble 11user and year，user75%-80%。

# %% [markdown]
# ####

# %%
# trade = pd.merge(left=trade, right=baby, how='left',
#                       on='user_id', suffixes=("_trade", "_baby"))

# %%
# data， so calculate2013year and 2014year
repurchase_data_2013 = trade[(trade.day >= datetime(
    2013, 1, 1)) & (trade.day <= datetime(2013, 12, 31))]
repurchase_data_2014 = trade[(trade.day >= datetime(
    2014, 1, 1)) & (trade.day <= datetime(2014, 12, 31))]

# %%
# based on month and useridminute
group_2013 = repurchase_data_2013.groupby(
    by=[repurchase_data_2013.day.dt.month, 'user_id'])
group_2014 = repurchase_data_2014.groupby(
    by=[repurchase_data_2014.day.dt.month, 'user_id'])

# %%
repurchase_data_2013.groupby(
    by=[repurchase_data_2013.day.dt.month, 'user_id']).size()[[1]].sum()
# Out:
# 628

# %%
def cmonthPurchaseRate(data):
    """
    importbased on month and useridminutedata
    """
    rate = []
    for i in range(1, 13):
        cmonth_bought_user = data.size()[[i]].sum()
        cmonth_repurchase_user = (data.size()[[i]] > 1).sum()
        rate.append(round(cmonth_repurchase_user/cmonth_bought_user, 4))
    return rate

# %%
purchase_rate_month_2013 = cmonthPurchaseRate(group_2013)
purchase_rate_month_2014 = cmonthPurchaseRate(group_2014)

# %%
pyc.Line().add_xaxis(xaxis_data=[x for x in range(1, 13)]
                     ).add_yaxis(
    series_name='2013yearmonth', y_axis=purchase_rate_month_2013
).add_yaxis(series_name='2014yearmonth', y_axis=purchase_rate_month_2014
            ).set_series_opts(label_opts=opts.LabelOpts(is_show=False)).set_global_opts(title_opts=opts.TitleOpts(title="month", subtitle="2013year2014yearmonth"), toolbox_opts=opts.ToolboxOpts(), tooltip_opts=opts.TooltipOpts(is_show=True, trigger='axis')).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3b2f7d9ec30f4deca0f84932439d0355" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3b2f7d9ec30f4deca0f84932439d0355 = echarts.init(
#                     document.getElementById('3b2f7d9ec30f4deca0f84932439d0355'), 'white', {renderer: 'canvas'});
#                 var option_3b2f7d9ec30f4deca0f84932439d0355 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
# 
# based on minute，
t = trade.groupby(by=['cat1', 'user_id']).size()
purchase_dict={}
for i in trade.cat1.unique():
    c = t.loc[i].value_counts()
    purchase_dict[i]=((c.sum()-c[:1])/c[:1]).values[0].round(4)
plt.figure(figsize=(10,6))
sns.barplot(x=list(purchase_dict.keys()),y=list(purchase_dict.values()))
plt.title("",fontdict=fontdict)
plt.show()

# %% [markdown]
# 4month、10month11monthhas usermonth，yes，，1%，useryes，，descriptionuserAnalyzeProduct，， e.g., Shopping。

# %% [markdown]
# ### ProductSales

# %%
# ProductSales
cat = trade.groupby("cat1")['buy_mount'].sum()
sns.barplot(x=cat.index, y=cat.values)
plt.title("ProductSales")
plt.xlabel("Product")
plt.show()

# %%
# 
cat_aver_user = (trade.groupby("cat1")['buy_mount'].sum(
) / trade.groupby("cat1")['user_id'].count()).sort_values(ascending=False)
sns.barplot(x=cat_aver_user.index, y=cat_aver_user.values)
plt.title("Product")
plt.xlabel("Product")
plt.show()

# %%
# Count
cat_count = trade.groupby("cat1")['cat_id'].count()
sns.barplot(x=cat_count.index, y=cat_count.values)
plt.title("ProductCount")
plt.xlabel("Product")
plt.show()

# %% [markdown]
# 28 and 50008168，38 although 、yes，descriptionuser38hour，houruserAnalyze，can 38，Sales

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#" data-toc-modified-id="-1"></a></span></li><li><span><a href="#1.-" data-toc-modified-id="1.--2">1. </a></span></li><li><span><a href="#2." data-toc-modified-id="2.-3">2.</a></span></li><li><span><a href="#3.label" data-toc-modified-id="3.label-4">3.label</a></span></li><li><span><a href="#4.data" data-toc-modified-id="4.data-5">4.data</a></span></li><li><span><a href="#5.Y【&amp;】" data-toc-modified-id="5.Y【&amp;】-6">5.Y【&amp;】</a></span></li><li><span><a href="#6.——Y" data-toc-modified-id="6.——Y-7">6.——Y</a></span></li><li><span><a href="#7.——X" data-toc-modified-id="7.——X-8">7.——X</a></span></li><li><span><a href="#8." data-toc-modified-id="8.-9">8.</a></span></li><li><span><a href="#9." data-toc-modified-id="9.-10">9.</a></span></li><li><span><a href="#10." data-toc-modified-id="10.-11">10.</a></span></li><li><span><a href="#11.——inside" data-toc-modified-id="11.——inside-12">11.——inside</a></span></li><li><span><a href="#12.——slider" data-toc-modified-id="12.——slider-13">12.——slider</a></span></li><li><span><a href="#13.——slider&amp;inside" data-toc-modified-id="13.——slider&amp;inside-14">13.——slider&amp;inside</a></span></li><li><span><a href="#14.XY" data-toc-modified-id="14.XY-15">14.XY</a></span></li><li><span><a href="#15.Effectiveness" data-toc-modified-id="15.Effectiveness-16">15.Effectiveness</a></span></li><li><span><a href="#15." data-toc-modified-id="15.-17">15.</a></span></li><li><span><a href="#16.()" data-toc-modified-id="16.()-18">16.()</a></span></li><li><span><a href="#17.()" data-toc-modified-id="17.()-19">17.()</a></span></li><li><span><a href="#18.minute" data-toc-modified-id="18.minute-20">18.minute</a></span></li><li><span><a href="#19.minute" data-toc-modified-id="19.minute-21">19.minute</a></span></li><li><span><a href="#20.through " data-toc-modified-id="20.through -22">20.through </a></span></li><li><span><a href="#21.Area" data-toc-modified-id="21.Area-23">21.Area</a></span></li><li><span><a href="#22.Area" data-toc-modified-id="22.Area-24">22.Area</a></span></li><li><span><a href="#23.（LineStyleOpts）" data-toc-modified-id="23.（LineStyleOpts）-25">23.（LineStyleOpts）</a></span></li><li><span><a href="#24.-Effectiveness" data-toc-modified-id="24.-Effectiveness-26">24. Effectiveness</a></span></li><li><span><a href="#25.processing" data-toc-modified-id="25.processing-27">25.processing</a></span></li><li><span><a href="#26.-(max，mean)" data-toc-modified-id="26.-(max，mean)-28">26. (max，mean)</a></span></li><li><span><a href="#27." data-toc-modified-id="27.-29">27.</a></span></li><li><span><a href="#28." data-toc-modified-id="28.-30">28.</a></span></li><li><span><a href="#29.minute" data-toc-modified-id="29.minute-31">29.minute</a></span></li><li><span><a href="#30." data-toc-modified-id="30.-32">30.</a></span></li><li><span><a href="#31." data-toc-modified-id="31.-33">31.</a></span></li><li><span><a href="#32.daycell" data-toc-modified-id="32.daycell-34">32.daycell</a></span></li><li><span><a href="#33.daylabel" data-toc-modified-id="33.daylabel-35">33.daylabel</a></span></li><li><span><a href="#34.GEO" data-toc-modified-id="34.GEO-36">34.GEO</a></span></li><li><span><a href="#35.GEOusing" data-toc-modified-id="35.GEOusing-37">35.GEOusing</a></span></li><li><span><a href="#36.GEO-Effectiveness" data-toc-modified-id="36.GEO-Effectiveness-38">36.GEO Effectiveness</a></span></li><li><span><a href="#37.GEO" data-toc-modified-id="37.GEO-39">37.GEO</a></span></li><li><span><a href="#38.GEO-" data-toc-modified-id="38.GEO--40">38.GEO </a></span></li><li><span><a href="#39." data-toc-modified-id="39.-41">39.</a></span></li><li><span><a href="#40.datalabel" data-toc-modified-id="40.datalabel-42">40.datalabel</a></span></li><li><span><a href="#41." data-toc-modified-id="41.-43">41.</a></span></li><li><span><a href="#42.（）" data-toc-modified-id="42.（）-44">42.（）</a></span></li><li><span><a href="#43.（&amp;Color）" data-toc-modified-id="43.（&amp;Color）-45">43.（&amp;Color）</a></span></li><li><span><a href="#44.（&amp;Color&amp;）" data-toc-modified-id="44.（&amp;Color&amp;）-46">44.（&amp;Color&amp;）</a></span></li><li><span><a href="#45.Color" data-toc-modified-id="45.Color-47">45.Color</a></span></li><li><span><a href="#46.Word Cloud" data-toc-modified-id="46.Word Cloud-48">46.Word Cloud</a></span></li><li><span><a href="#47.Map" data-toc-modified-id="47.Map-49">47.Map</a></span></li><li><span><a href="#48.Page" data-toc-modified-id="48.Page-50">48.Page</a></span></li><li><span><a href="#49.Tab" data-toc-modified-id="49.Tab-51">49.Tab</a></span></li><li><span><a href="#50.Timeline-" data-toc-modified-id="50.Timeline--52">50.Timeline </a></span></li></ul></div>

# %% [markdown]
# ####
#
# * 50pyecharts，contains，cellcontains，；
#
# * ，contains；
#
# * based on `pyecharts V1.7.1`，different has ，yes；

# %% [markdown]
# #### 1.
#
# * different datausingstack ；

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def bar_stack():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(Faker.choose())
    # stack
    bar.add_yaxis('A', Faker.values(), stack='stack1')
    bar.add_yaxis('B', Faker.values(), stack='stack1')
    bar.add_yaxis('C', Faker.values(), stack='stack2')
    return bar



chart = bar_stack()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a38935ffc2c34536bfdee41700fc7256" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a38935ffc2c34536bfdee41700fc7256 = echarts.init(
#                     document.getElementById('a38935ffc2c34536bfdee41700fc7256'), 'light', {renderer: 'canvas'});
#                 var option_a38935ffc2c34536bfdee41700fc7256 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "legendHoverLink": true,
#             "data": [
#                 117,
#                 86,
#                 119,
#                 83,
#                 63,
#                 42,
#                 145
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "legendHoverLink": true,
#             "data": [
#                 73,
#                 36,
#                 107,
#                 146,
#                 69,
#                 85,
#                 149
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "C",
#             "legendHoverLink": true,
#             "data": [
#                 29,
#                 88,
#                 23,
#                 83,
#                 114,
#                 147,
#                 58
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "stack2",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B",
#                 "C"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true,
#                 "C": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_a38935ffc2c34536bfdee41700fc7256.setOption(option_a38935ffc2c34536bfdee41700fc7256);
#         });
#     </script>

# %% [markdown]
# #### 2.
#
# * labelhour，，data&label；

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def bar_with_axis_off():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(Faker.choose())
    bar.add_yaxis('', Faker.values())
    # labelhour，，
    bar.set_series_opts(label_opts=opts.LabelOpts(position='insideLeft', formatter='{b}:{c}'))
    bar.set_global_opts(xaxis_opts=opts.AxisOpts(is_show=False),
                        yaxis_opts=opts.AxisOpts(is_show=False))
    bar.reversal_axis()
    return bar


chart = bar_with_axis_off()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e7eeadaf68b14795a5e3ec13346af440" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e7eeadaf68b14795a5e3ec13346af440 = echarts.init(
#                     document.getElementById('e7eeadaf68b14795a5e3ec13346af440'), 'light', {renderer: 'canvas'});
#                 var option_e7eeadaf68b14795a5e3ec13346af440 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 100,
#                 102,
#                 97,
#                 119,
#                 31,
#                 140,
#                 140
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "insideLeft",
#                 "margin": 8,
#                 "formatter": "{b}:{c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_e7eeadaf68b14795a5e3ec13346af440.setOption(option_e7eeadaf68b14795a5e3ec13346af440);
#         });
#     </script>

# %% [markdown]
# #### 3.label

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data = list(range(2010, 2020))
y_data = [random.randint(20, 200) for _ in range(len(x_data))]


def bar_with_custom_axis_label():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(x_data)
    bar.add_yaxis('', y_data)

    bar.set_global_opts(xaxis_opts=opts.AxisOpts(
        # label，Year`year`
        axislabel_opts=opts.LabelOpts(formatter='{value}year')))
    return bar


chart = bar_with_custom_axis_label()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="43226425742d40448bc3009936b476a4" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_43226425742d40448bc3009936b476a4 = echarts.init(
#                     document.getElementById('43226425742d40448bc3009936b476a4'), 'light', {renderer: 'canvas'});
#                 var option_43226425742d40448bc3009936b476a4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 103,
#                 143,
#                 35,
#                 77,
#                 191,
#                 198,
#                 53,
#                 133,
#                 123,
#                 41
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{value}\u5e74"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 2010,
#                 2011,
#                 2012,
#                 2013,
#                 2014,
#                 2015,
#                 2016,
#                 2017,
#                 2018,
#                 2019
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_43226425742d40448bc3009936b476a4.setOption(option_43226425742d40448bc3009936b476a4);
#         });
#     </script>

# %% [markdown]
# #### 4.data
#
# * xdatayesusing，usinghour；

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data = [random.randint(0, 20) for _ in range(100)]
y_data = [random.randint(0, 50) for _ in range(100)]


def scatter_with_value_xaxis():
    scatter = Scatter(init_opts=opts.InitOpts(theme='light',
                                              width='1000px',
                                              height='600px'))
    scatter.add_xaxis(x_data)
    scatter.add_yaxis('', y_data)
    # Xdatadata，
    scatter.set_global_opts(xaxis_opts=opts.AxisOpts(type_="value"))
    return scatter

chart = scatter_with_value_xaxis()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="41cc9c7e92194b019dd44f83e26b5071" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_41cc9c7e92194b019dd44f83e26b5071 = echarts.init(
#                     document.getElementById('41cc9c7e92194b019dd44f83e26b5071'), 'light', {renderer: 'canvas'});
#                 var option_41cc9c7e92194b019dd44f83e26b5071 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     6,
#                     41
#                 ],
#                 [
#                     9,
#                     9
#                 ],
#                 [
#                     15,
#                     11
#                 ],
#                 [
#                     20,
#                     42
#                 ],
#                 [
#                     20,
#                     9
#                 ],
#                 [
#                     11,
#                     6
#                 ],
#                 [
#                     12,
#                     9
#                 ],
#                 [
#                     17,
#                     36
#                 ],
#                 [
#                     18,
#                     46
#                 ],
#                 [
#                     7,
#                     31
#                 ],
#                 [
#                     16,
#                     44
#                 ],
#                 [
#                     16,
#                     28
#                 ],
#                 [
#                     14,
#                     43
#                 ],
#                 [
#                     2,
#                     31
#                 ],
#                 [
#                     16,
#                     9
#                 ],
#                 [
#                     11,
#                     11
#                 ],
#                 [
#                     3,
#                     15
#                 ],
#                 [
#                     2,
#                     15
#                 ],
#                 [
#                     14,
#                     9
#                 ],
#                 [
#                     2,
#                     37
#                 ],
#                 [
#                     0,
#                     49
#                 ],
#                 [
#                     10,
#                     9
#                 ],
#                 [
#                     1,
#                     17
#                 ],
#                 [
#                     8,
#                     30
#                 ],
#                 [
#                     16,
#                     23
#                 ],
#                 [
#                     4,
#                     28
#                 ],
#                 [
#                     10,
#                     30
#                 ],
#                 [
#                     14,
#                     38
#                 ],
#                 [
#                     6,
#                     46
#                 ],
#                 [
#                     20,
#                     38
#                 ],
#                 [
#                     7,
#                     1
#                 ],
#                 [
#                     2,
#                     43
#                 ],
#                 [
#                     13,
#                     16
#                 ],
#                 [
#                     5,
#                     18
#                 ],
#                 [
#                     18,
#                     17
#                 ],
#                 [
#                     3,
#                     32
#                 ],
#                 [
#                     20,
#                     41
#                 ],
#                 [
#                     1,
#                     39
#                 ],
#                 [
#                     8,
#                     0
#                 ],
#                 [
#                     10,
#                     28
#                 ],
#                 [
#                     2,
#                     3
#                 ],
#                 [
#                     3,
#                     23
#                 ],
#                 [
#                     3,
#                     43
#                 ],
#                 [
#                     5,
#                     9
#                 ],
#                 [
#                     11,
#                     28
#                 ],
#                 [
#                     19,
#                     3
#                 ],
#                 [
#                     12,
#                     30
#                 ],
#                 [
#                     3,
#                     23
#                 ],
#                 [
#                     9,
#                     32
#                 ],
#                 [
#                     6,
#                     34
#                 ],
#                 [
#                     2,
#                     45
#                 ],
#                 [
#                     1,
#                     24
#                 ],
#                 [
#                     18,
#                     48
#                 ],
#                 [
#                     18,
#                     10
#                 ],
#                 [
#                     2,
#                     5
#                 ],
#                 [
#                     7,
#                     22
#                 ],
#                 [
#                     0,
#                     4
#                 ],
#                 [
#                     20,
#                     35
#                 ],
#                 [
#                     0,
#                     45
#                 ],
#                 [
#                     9,
#                     2
#                 ],
#                 [
#                     3,
#                     17
#                 ],
#                 [
#                     5,
#                     28
#                 ],
#                 [
#                     18,
#                     45
#                 ],
#                 [
#                     7,
#                     11
#                 ],
#                 [
#                     11,
#                     11
#                 ],
#                 [
#                     7,
#                     40
#                 ],
#                 [
#                     8,
#                     5
#                 ],
#                 [
#                     18,
#                     21
#                 ],
#                 [
#                     13,
#                     9
#                 ],
#                 [
#                     6,
#                     4
#                 ],
#                 [
#                     10,
#                     2
#                 ],
#                 [
#                     20,
#                     24
#                 ],
#                 [
#                     0,
#                     45
#                 ],
#                 [
#                     14,
#                     4
#                 ],
#                 [
#                     20,
#                     22
#                 ],
#                 [
#                     4,
#                     31
#                 ],
#                 [
#                     3,
#                     29
#                 ],
#                 [
#                     10,
#                     14
#                 ],
#                 [
#                     3,
#                     36
#                 ],
#                 [
#                     3,
#                     47
#                 ],
#                 [
#                     18,
#                     9
#                 ],
#                 [
#                     13,
#                     15
#                 ],
#                 [
#                     11,
#                     8
#                 ],
#                 [
#                     11,
#                     25
#                 ],
#                 [
#                     10,

# %% [markdown]
# #### 5.Y【&】
#
# * yesBar and Line，Bar and Linerespectivelydifferent Y；

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data = ['', '', '', '', '', '']
y_data_1 = [random.randint(10, 50) for _ in range(len(x_data))]
y_data_2 = [random.randint(100, 500) for _ in range(len(x_data))]


def bar_line_combine_with_two_axis():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(x_data)
    # Y
    bar.extend_axis(yaxis=opts.AxisOpts())
    bar.add_yaxis('Y', y_data_1, yaxis_index=0)

    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='1000px',
                                        height='600px'))
    line.add_xaxis(x_data)
    # linedatathrough yaxis_indexY
    line.add_yaxis('Y', y_data_2, yaxis_index=1)

    bar.overlap(line)
    return bar


chart = bar_line_combine_with_two_axis()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3f17798b081d46df9345d029e46f7029" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3f17798b081d46df9345d029e46f7029 = echarts.init(
#                     document.getElementById('3f17798b081d46df9345d029e46f7029'), 'light', {renderer: 'canvas'});
#                 var option_3f17798b081d46df9345d029e46f7029 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5de6\u8fb9Y\u8f74",
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 19,
#                 47,
#                 30,
#                 41,
#                 30,
#                 40
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u53f3\u8fb9Y\u8f74",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u9999\u8549",
#                     147
#                 ],
#                 [
#                     "\u68a8\u5b50",
#                     343
#                 ],
#                 [
#                     "\u6c34\u871c\u6843",
#                     210
#                 ],
#                 [
#                     "\u6838\u6843",
#                     121
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     276
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     319
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5de6\u8fb9Y\u8f74",
#                 "\u53f3\u8fb9Y\u8f74"
#             ],
#             "selected": {
#                 "\u5de6\u8fb9Y\u8f74": true,
#                 "\u53f3\u8fb9Y\u8f74": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u9999\u8549",
#                 "\u68a8\u5b50",
#                 "\u6c34\u871c\u6843",
#                 "\u6838\u6843",
#                 "\u897f\u74dc",
#                 "\u82f9\u679c"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_3f17798b081d46df9345d029e46f7029.setOption(option_3f17798b081d46df9345d029e46f7029);
#         });
#     </script>

# %% [markdown]
# #### 6.——Y

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data = ['', '', '', '', '', '']
y_data_1 = [random.randint(10, 50) for _ in range(len(x_data))]
y_data_2 = [random.randint(100, 500) for _ in range(len(x_data))]


def bar_with_multiple_axis():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(x_data)
    # Y
    bar.extend_axis(yaxis=opts.AxisOpts())
    # respectivelyusing Y
    bar.add_yaxis('Y', y_data_1, yaxis_index=0)
    bar.add_yaxis('Y', y_data_2, yaxis_index=1)
    return bar


chart = bar_with_multiple_axis()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6861b2fd803a4ba38c197f867aefdc63" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6861b2fd803a4ba38c197f867aefdc63 = echarts.init(
#                     document.getElementById('6861b2fd803a4ba38c197f867aefdc63'), 'light', {renderer: 'canvas'});
#                 var option_6861b2fd803a4ba38c197f867aefdc63 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5de6\u8fb9Y\u8f74",
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 18,
#                 29,
#                 15,
#                 23,
#                 27,
#                 34
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u53f3\u8fb9Y\u8f74",
#             "yAxisIndex": 1,
#             "legendHoverLink": true,
#             "data": [
#                 347,
#                 279,
#                 449,
#                 225,
#                 475,
#                 427
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5de6\u8fb9Y\u8f74",
#                 "\u53f3\u8fb9Y\u8f74"
#             ],
#             "selected": {
#                 "\u5de6\u8fb9Y\u8f74": true,
#                 "\u53f3\u8fb9Y\u8f74": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u9999\u8549",
#                 "\u68a8\u5b50",
#                 "\u6c34\u871c\u6843",
#                 "\u6838\u6843",
#                 "\u897f\u74dc",
#                 "\u82f9\u679c"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_6861b2fd803a4ba38c197f867aefdc63.setOption(option_6861b2fd803a4ba38c197f867aefdc63);
#         });
#     </script>

# %% [markdown]
# #### 7.——X

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data_1 = ["2020/10/{}".format(i + 1) for i in range(30)]
x_data_2 = ["2019/10/{}".format(i + 1) for i in range(30)]
y_data_1 = [random.randint(10, 50) for _ in range(30)]
y_data_2 = [random.randint(20, 60) for _ in range(30)]


def line_with_two_xaxis():
    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='1000px',
                                        height='600px'))
    line.add_xaxis(x_data_1)
    # x
    line.extend_axis(xaxis_data=x_data_2, xaxis=opts.AxisOpts())
    line.add_yaxis('X', y_data_1)
    line.add_yaxis('X', y_data_2)
    return line


chart = line_with_two_xaxis()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="54832177ec2243f5b1c76f3a9f8d822e" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_54832177ec2243f5b1c76f3a9f8d822e = echarts.init(
#                     document.getElementById('54832177ec2243f5b1c76f3a9f8d822e'), 'light', {renderer: 'canvas'});
#                 var option_54832177ec2243f5b1c76f3a9f8d822e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u4e0b\u9762X\u8f74",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020/10/1",
#                     29
#                 ],
#                 [
#                     "2020/10/2",
#                     12
#                 ],
#                 [
#                     "2020/10/3",
#                     17
#                 ],
#                 [
#                     "2020/10/4",
#                     19
#                 ],
#                 [
#                     "2020/10/5",
#                     30
#                 ],
#                 [
#                     "2020/10/6",
#                     33
#                 ],
#                 [
#                     "2020/10/7",
#                     24
#                 ],
#                 [
#                     "2020/10/8",
#                     30
#                 ],
#                 [
#                     "2020/10/9",
#                     24
#                 ],
#                 [
#                     "2020/10/10",
#                     16
#                 ],
#                 [
#                     "2020/10/11",
#                     13
#                 ],
#                 [
#                     "2020/10/12",
#                     50
#                 ],
#                 [
#                     "2020/10/13",
#                     46
#                 ],
#                 [
#                     "2020/10/14",
#                     15
#                 ],
#                 [
#                     "2020/10/15",
#                     34
#                 ],
#                 [
#                     "2020/10/16",
#                     13
#                 ],
#                 [
#                     "2020/10/17",
#                     33
#                 ],
#                 [
#                     "2020/10/18",
#                     30
#                 ],
#                 [
#                     "2020/10/19",
#                     46
#                 ],
#                 [
#                     "2020/10/20",
#                     18
#                 ],
#                 [
#                     "2020/10/21",
#                     42
#                 ],
#                 [
#                     "2020/10/22",
#                     50
#                 ],
#                 [
#                     "2020/10/23",
#                     27
#                 ],
#                 [
#                     "2020/10/24",
#                     20
#                 ],
#                 [
#                     "2020/10/25",
#                     28
#                 ],
#                 [
#                     "2020/10/26",
#                     27
#                 ],
#                 [
#                     "2020/10/27",
#                     11
#                 ],
#                 [
#                     "2020/10/28",
#                     10
#                 ],
#                 [
#                     "2020/10/29",
#                     43
#                 ],
#                 [
#                     "2020/10/30",
#                     23
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u4e0a\u9762X\u8f74",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020/10/1",
#                     37
#                 ],
#                 [
#                     "2020/10/2",
#                     21
#                 ],
#                 [
#                     "2020/10/3",
#                     53
#                 ],
#                 [
#                     "2020/10/4",
#                     26
#                 ],
#                 [
#                     "2020/10/5",
#                     41
#                 ],
#                 [
#                     "2020/10/6",
#                     48
#                 ],
#                 [
#                     "2020/10/7",
#                     52
#                 ],
#                 [
#                     "2020/10/8",
#                     59
#                 ],
#                 [
#                     "2020/10/9",
#                     59
#                 ],
#                 [
#                     "2020/10/10",
#                     21
#                 ],
#                 [
#                     "2020/10/11",
#                     56
#                 ],
#                 [
#                     "2020/10/12",
#                     50
#                 ],
#                 [
#                     "2020/10/13",
#                     36
#                 ],
#                 [
#                     "2020/10/14",
#                     50
#                 ],
#                 [
#                     "2020/10/15",
#                     23
#                 ],
#                 [
#                     "2020/10/16",
#                     40
#                 ],
#                 [
#                     "2020/10/17",
#                     25
#                 ],
#                 [
#                     "2020/10/18",
#                     26
#                 ],
#                 [
#                     "2020/10/19",
#                     35
#                 ],
#                 [
#                     "2020/10/20",
#                     36
#                 ],
#                 [
#                     "2020/10/21",
#                     27
#                 ],
#                 [
#                     "2020/10/22",
#                     25
#                 ],
#                 [
#                     "2020/10/23",
#                     25
#                 ],
#                 [
#                     "2020/10/24",
#                     22
#                 ],
#                 [
#                     "2020/10/25",
#                     53
#                 ],
#                 [
#                     "2020/10/26",
#                     43
#                 ],
#                 [
#                     "2020/10/27",
#                     34
#                 ],
#                 [
#                     "2020/10/28",
#                     41
#                 ],
#                 [
#                     "2020/10/29",
#                     26
#                 ],
#                 [
#                     "2020/10/30",
#                     53
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle":

# %% [markdown]
# #### 8.
#
# * Analyzedifferent different icon
# * yesdataminuteicon，through grid

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

ios_icon = 'path://M24.734 17.003c-0.040-4.053 3.305-5.996 3.454-6.093-1.88-2.751-4.808-3.127-5.851-3.171-2.492-0.252-4.862 1.467-6.127 1.467-1.261 0-3.213-1.43-5.28-1.392-2.716 0.040-5.221 1.579-6.619 4.012-2.822 4.897-0.723 12.151 2.028 16.123 1.344 1.944 2.947 4.127 5.051 4.049 2.026-0.081 2.793-1.311 5.242-1.311s3.138 1.311 5.283 1.271c2.18-0.041 3.562-1.981 4.897-3.931 1.543-2.255 2.179-4.439 2.216-4.551-0.048-0.022-4.252-1.632-4.294-6.473zM20.705 5.11c1.117-1.355 1.871-3.235 1.665-5.11-1.609 0.066-3.559 1.072-4.713 2.423-1.036 1.199-1.942 3.113-1.699 4.951 1.796 0.14 3.629-0.913 4.747-2.264z'
android_icon = 'path://M28 12c-1.1 0-2 0.9-2 2v8c0 1.1 0.9 2 2 2s2-0.9 2-2v-8c0-1.1-0.9-2-2-2zM4 12c-1.1 0-2 0.9-2 2v8c0 1.1 0.9 2 2 2s2-0.9 2-2v-8c0-1.1-0.9-2-2-2zM7 23c0 1.657 1.343 3 3 3v0 4c0 1.1 0.9 2 2 2s2-0.9 2-2v-4h4v4c0 1.1 0.9 2 2 2s2-0.9 2-2v-4c1.657 0 3-1.343 3-3v-11h-18v11zM24.944 10c-0.304-2.746-1.844-5.119-4.051-6.551l1.001-2.001c0.247-0.494 0.047-1.095-0.447-1.342s-1.095-0.047-1.342 0.447l-1.004 2.009-0.261-0.104c-0.893-0.297-1.848-0.458-2.84-0.458s-1.947 0.161-2.84 0.458l-0.261 0.104-1.004-2.009c-0.247-0.494-0.848-0.694-1.342-0.447s-0.694 0.848-0.447 1.342l1.001 2.001c-2.207 1.433-3.747 3.805-4.051 6.551v1h17.944v-1h-0.056zM13 8c-0.552 0-1-0.448-1-1s0.447-0.999 0.998-1c0.001 0 0.002 0 0.003 0s0.001-0 0.002-0c0.551 0.001 0.998 0.448 0.998 1s-0.448 1-1 1zM19 8c-0.552 0-1-0.448-1-1s0.446-0.999 0.998-1c0 0 0.001 0 0.002 0s0.002-0 0.003-0c0.551 0.001 0.998 0.448 0.998 1s-0.448 1-1 1z'

x_data = ["2020/7/{}".format(i + 1) for i in range(10)]

# data
y_data_1 = [random.randint(10, 20) for i in range(len(x_data))]
y_data_2 = [random.randint(15, 25) for i in range(len(x_data))]


def bar_custom_legend_symbol():
    # targeting different different icon
    # dataminuteicon，through grid
    ios_bar = Bar()
    ios_bar.add_xaxis(x_data)
    ios_bar.add_yaxis('IOS', y_data_1)
    ios_bar.set_global_opts(legend_opts=opts.LegendOpts(legend_icon=ios_icon,
                                                        pos_right='15%'))

    az_bar = Bar()
    az_bar.add_xaxis(x_data)
    az_bar.add_yaxis('Android', y_data_2)
    az_bar.set_global_opts(legend_opts=opts.LegendOpts(legend_icon=android_icon,
                                                       pos_right='5%'))

    # az_bar and ios_bar
    grid = Grid(init_opts=opts.InitOpts(theme='light',
                                        width='1000px',
                                        height='600px'))
    grid.add(ios_bar, is_control_axis_index=True, grid_opts=opts.GridOpts())
    grid.add(az_bar, is_control_axis_index=True, grid_opts=opts.GridOpts())
    return grid


chart = bar_custom_legend_symbol()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fb311389f60d4f9db063375de9397e4d" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fb311389f60d4f9db063375de9397e4d = echarts.init(
#                     document.getElementById('fb311389f60d4f9db063375de9397e4d'), 'light', {renderer: 'canvas'});
#                 var option_fb311389f60d4f9db063375de9397e4d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [],
#     "series": [
#         {
#             "type": "bar",
#             "name": "IOS",
#             "legendHoverLink": true,
#             "data": [
#                 13,
#                 14,
#                 11,
#                 20,
#                 20,
#                 17,
#                 10,
#                 19,
#                 10,
#                 18
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Android",
#             "legendHoverLink": true,
#             "data": [
#                 22,
#                 19,
#                 18,
#                 24,
#                 18,
#                 15,
#                 25,
#                 17,
#                 22,
#                 17
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "IOS"
#             ],
#             "selected": {
#                 "IOS": true
#             },
#             "show": true,
#             "right": "15%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "icon": "path://M24.734 17.003c-0.040-4.053 3.305-5.996 3.454-6.093-1.88-2.751-4.808-3.127-5.851-3.171-2.492-0.252-4.862 1.467-6.127 1.467-1.261 0-3.213-1.43-5.28-1.392-2.716 0.040-5.221 1.579-6.619 4.012-2.822 4.897-0.723 12.151 2.028 16.123 1.344 1.944 2.947 4.127 5.051 4.049 2.026-0.081 2.793-1.311 5.242-1.311s3.138 1.311 5.283 1.271c2.18-0.041 3.562-1.981 4.897-3.931 1.543-2.255 2.179-4.439 2.216-4.551-0.048-0.022-4.252-1.632-4.294-6.473zM20.705 5.11c1.117-1.355 1.871-3.235 1.665-5.11-1.609 0.066-3.559 1.072-4.713 2.423-1.036 1.199-1.942 3.113-1.699 4.951 1.796 0.14 3.629-0.913 4.747-2.264z",
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         },
#         {
#             "data": [
#                 "Android"
#             ],
#             "selected": {
#                 "Android": true
#             },
#             "show": true,
#             "right": "5%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "icon": "path://M28 12c-1.1 0-2 0.9-2 2v8c0 1.1 0.9 2 2 2s2-0.9 2-2v-8c0-1.1-0.9-2-2-2zM4 12c-1.1 0-2 0.9-2 2v8c0 1.1 0.9 2 2 2s2-0.9 2-2v-8c0-1.1-0.9-2-2-2zM7 23c0 1.657 1.343 3 3 3v0 4c0 1.1 0.9 2 2 2s2-0.9 2-2v-4h4v4c0 1.1 0.9 2 2 2s2-0.9 2-2v-4c1.657 0 3-1.343 3-3v-11h-18v11zM24.944 10c-0.304-2.746-1.844-5.119-4.051-6.551l1.001-2.001c0.247-0.494 0.047-1.095-0.447-1.342s-1.095-0.047-1.342 0.447l-1.004 2.009-0.261-0.104c-0.893-0.297-1.848-0.458-2.84-0.458s-1.947 0.161-2.84 0.458l-0.261 0.104-1.004-2.009c-0.247-0.494-0.848-0.694-1.342-0.447s-0.694 0.848-0.447 1.342l1.001 2.001c-2.207 1.433-3.747 3.805-4.051 6.551v1h17.944v-1h-0.056zM13 8c-0.552 0-1-0.448-1-1s0.447-0.999 0.998-1c0.001 0 0.002 0 0.003 0s0.001-0 0.002-0c0.551 0.001 0.998 0.448 0.998 1s-0.448 1-1 1zM19 8c-0.552 0-1-0.448-1-1s0.446-0.999 0.998-1c0 0 0.001 0 0.002 0s0.002-0 0.003-0c0.551 0.001 0.998 0.448 0.998 1s-0.448 1-1 1z",
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020/7/1",
#                 "2020/7/2",
#                 "2020/7/3",
#                 "2020/7/4",
#                 "2020/7/5",
#                 "2020/7/6",
#                 "2020/7/7",
#                 "2020/7/8",
#                 "2020/7/9",
#                 "2020/7/10"
#             ]
#         },
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 1,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"

# %% [markdown]
# #### 9.

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker

def bar_single_selected():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(Faker.choose())
    bar.add_yaxis('A', Faker.values())
    bar.add_yaxis('B', Faker.values())
    # 
    bar.set_global_opts(legend_opts=opts.LegendOpts(selected_mode='single'))
    return bar


chart = bar_single_selected()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e3378fd100a94f34a4c07c87ced5e8b2" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e3378fd100a94f34a4c07c87ced5e8b2 = echarts.init(
#                     document.getElementById('e3378fd100a94f34a4c07c87ced5e8b2'), 'light', {renderer: 'canvas'});
#                 var option_e3378fd100a94f34a4c07c87ced5e8b2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "legendHoverLink": true,
#             "data": [
#                 102,
#                 75,
#                 37,
#                 33,
#                 132,
#                 93,
#                 90
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "legendHoverLink": true,
#             "data": [
#                 119,
#                 48,
#                 97,
#                 122,
#                 98,
#                 55,
#                 59
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "selectedMode": "single",
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_e3378fd100a94f34a4c07c87ced5e8b2.setOption(option_e3378fd100a94f34a4c07c87ced5e8b2);
#         });
#     </script>

# %% [markdown]
# #### 10.

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def bar_with_default_selected_series():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(Faker.choose())
    # A C
    bar.add_yaxis('A', Faker.values(), is_selected=True)
    bar.add_yaxis('B', Faker.values(), is_selected=False)
    bar.add_yaxis('C', Faker.values(), is_selected=True)
    return bar


chart = bar_with_default_selected_series()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="40cdb1ae1f384b0293e15170f4e562e3" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_40cdb1ae1f384b0293e15170f4e562e3 = echarts.init(
#                     document.getElementById('40cdb1ae1f384b0293e15170f4e562e3'), 'light', {renderer: 'canvas'});
#                 var option_40cdb1ae1f384b0293e15170f4e562e3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "legendHoverLink": true,
#             "data": [
#                 114,
#                 138,
#                 82,
#                 67,
#                 136,
#                 70,
#                 29
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "legendHoverLink": true,
#             "data": [
#                 68,
#                 41,
#                 30,
#                 68,
#                 106,
#                 131,
#                 133
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "C",
#             "legendHoverLink": true,
#             "data": [
#                 67,
#                 50,
#                 102,
#                 136,
#                 138,
#                 22,
#                 53
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B",
#                 "C"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": false,
#                 "C": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_40cdb1ae1f384b0293e15170f4e562e3.setOption(option_40cdb1ae1f384b0293e15170f4e562e3);
#         });
#     </script>

# %% [markdown]
# #### 11.——inside

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data = ["2020/10/{}".format(i + 1) for i in range(30)]

# data
y_data = [random.randint(10, 20) for i in range(len(x_data))]


def bar_datazoom_inside():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(x_data)
    bar.add_yaxis('', y_data)
    bar.set_global_opts(datazoom_opts=opts.DataZoomOpts(type_='inside',
                                                        range_start=50,   # ，50%-100%
                                                        range_end=100))
    return bar


chart = bar_datazoom_inside()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3b8627c10c8e4e20b82f07eebaacc251" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3b8627c10c8e4e20b82f07eebaacc251 = echarts.init(
#                     document.getElementById('3b8627c10c8e4e20b82f07eebaacc251'), 'light', {renderer: 'canvas'});
#                 var option_3b8627c10c8e4e20b82f07eebaacc251 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 20,
#                 13,
#                 19,
#                 18,
#                 20,
#                 14,
#                 13,
#                 14,
#                 20,
#                 12,
#                 18,
#                 17,
#                 13,
#                 10,
#                 16,
#                 10,
#                 15,
#                 20,
#                 11,
#                 15,
#                 17,
#                 18,
#                 15,
#                 20,
#                 11,
#                 16,
#                 13,
#                 12,
#                 18,
#                 13
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020/10/1",
#                 "2020/10/2",
#                 "2020/10/3",
#                 "2020/10/4",
#                 "2020/10/5",
#                 "2020/10/6",
#                 "2020/10/7",
#                 "2020/10/8",
#                 "2020/10/9",
#                 "2020/10/10",
#                 "2020/10/11",
#                 "2020/10/12",
#                 "2020/10/13",
#                 "2020/10/14",
#                 "2020/10/15",
#                 "2020/10/16",
#                 "2020/10/17",
#                 "2020/10/18",
#                 "2020/10/19",
#                 "2020/10/20",
#                 "2020/10/21",
#                 "2020/10/22",
#                 "2020/10/23",
#                 "2020/10/24",
#                 "2020/10/25",
#                 "2020/10/26",
#                 "2020/10/27",
#                 "2020/10/28",
#                 "2020/10/29",
#                 "2020/10/30"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "inside",
#         "showDetail": true,
#         "showDataShadow": true,
#         "realtime": true,
#         "start": 50,
#         "end": 100,
#         "orient": "horizontal",
#         "zoomLock": false,
#         "filterMode": "filter"
#     }
# };
#                 chart_3b8627c10c8e4e20b82f07eebaacc251.setOption(option_3b8627c10c8e4e20b82f07eebaacc251);
#         });
#     </script>

# %% [markdown]
# #### 12.——slider

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data = ["2020/10/{}".format(i + 1) for i in range(30)]

# data
y_data = [random.randint(10, 20) for i in range(len(x_data))]


def bar_with_datazoom_slider():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(x_data)
    bar.add_yaxis('', y_data)
    bar.set_global_opts(datazoom_opts=opts.DataZoomOpts(range_start=50,   # ，50%-100%
                                                        range_end=100))
    return bar


chart = bar_with_datazoom_slider()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5cc825b31c744b0886b25ff41499bf8e" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5cc825b31c744b0886b25ff41499bf8e = echarts.init(
#                     document.getElementById('5cc825b31c744b0886b25ff41499bf8e'), 'light', {renderer: 'canvas'});
#                 var option_5cc825b31c744b0886b25ff41499bf8e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 19,
#                 17,
#                 16,
#                 10,
#                 15,
#                 18,
#                 13,
#                 10,
#                 14,
#                 10,
#                 19,
#                 12,
#                 20,
#                 18,
#                 16,
#                 14,
#                 12,
#                 11,
#                 18,
#                 11,
#                 15,
#                 15,
#                 16,
#                 15,
#                 12,
#                 17,
#                 11,
#                 12,
#                 19,
#                 12
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020/10/1",
#                 "2020/10/2",
#                 "2020/10/3",
#                 "2020/10/4",
#                 "2020/10/5",
#                 "2020/10/6",
#                 "2020/10/7",
#                 "2020/10/8",
#                 "2020/10/9",
#                 "2020/10/10",
#                 "2020/10/11",
#                 "2020/10/12",
#                 "2020/10/13",
#                 "2020/10/14",
#                 "2020/10/15",
#                 "2020/10/16",
#                 "2020/10/17",
#                 "2020/10/18",
#                 "2020/10/19",
#                 "2020/10/20",
#                 "2020/10/21",
#                 "2020/10/22",
#                 "2020/10/23",
#                 "2020/10/24",
#                 "2020/10/25",
#                 "2020/10/26",
#                 "2020/10/27",
#                 "2020/10/28",
#                 "2020/10/29",
#                 "2020/10/30"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "showDetail": true,
#         "showDataShadow": true,
#         "realtime": true,
#         "start": 50,
#         "end": 100,
#         "orient": "horizontal",
#         "zoomLock": false,
#         "filterMode": "filter"
#     }
# };
#                 chart_5cc825b31c744b0886b25ff41499bf8e.setOption(option_5cc825b31c744b0886b25ff41499bf8e);
#         });
#     </script>

# %% [markdown]
# #### 13.——slider&inside

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data = ["2020/10/{}".format(i + 1) for i in range(30)]

# data
y_data = [random.randint(10, 20) for i in range(len(x_data))]


def bar_datazoom_both_way():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(x_data)
    bar.add_yaxis('', y_data)
    # through listdatazoom_opts
    bar.set_global_opts(datazoom_opts=[opts.DataZoomOpts(),
                                       opts.DataZoomOpts(type_='inside', range_start=50, range_end=100)])
    return bar


chart = bar_datazoom_both_way()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="924f8514ec13496d9a3e28b58167f4b2" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_924f8514ec13496d9a3e28b58167f4b2 = echarts.init(
#                     document.getElementById('924f8514ec13496d9a3e28b58167f4b2'), 'light', {renderer: 'canvas'});
#                 var option_924f8514ec13496d9a3e28b58167f4b2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 12,
#                 18,
#                 20,
#                 16,
#                 18,
#                 16,
#                 11,
#                 19,
#                 11,
#                 12,
#                 20,
#                 15,
#                 16,
#                 19,
#                 17,
#                 19,
#                 20,
#                 12,
#                 17,
#                 19,
#                 13,
#                 12,
#                 11,
#                 16,
#                 14,
#                 10,
#                 12,
#                 17,
#                 10,
#                 10
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020/10/1",
#                 "2020/10/2",
#                 "2020/10/3",
#                 "2020/10/4",
#                 "2020/10/5",
#                 "2020/10/6",
#                 "2020/10/7",
#                 "2020/10/8",
#                 "2020/10/9",
#                 "2020/10/10",
#                 "2020/10/11",
#                 "2020/10/12",
#                 "2020/10/13",
#                 "2020/10/14",
#                 "2020/10/15",
#                 "2020/10/16",
#                 "2020/10/17",
#                 "2020/10/18",
#                 "2020/10/19",
#                 "2020/10/20",
#                 "2020/10/21",
#                 "2020/10/22",
#                 "2020/10/23",
#                 "2020/10/24",
#                 "2020/10/25",
#                 "2020/10/26",
#                 "2020/10/27",
#                 "2020/10/28",
#                 "2020/10/29",
#                 "2020/10/30"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "dataZoom": [
#         {
#             "show": true,
#             "type": "slider",
#             "showDetail": true,
#             "showDataShadow": true,
#             "realtime": true,
#             "start": 20,
#             "end": 80,
#             "orient": "horizontal",
#             "zoomLock": false,
#             "filterMode": "filter"
#         },
#         {
#             "show": true,
#             "type": "inside",
#             "showDetail": true,
#             "showDataShadow": true,
#             "realtime": true,
#             "start": 50,
#             "end": 100,
#             "orient": "horizontal",
#             "zoomLock": false,
#             "filterMode": "filter"
#         }
#     ]
# };
#                 chart_924f8514ec13496d9a3e28b58167f4b2.setOption(option_924f8514ec13496d9a3e28b58167f4b2);
#         });
#     </script>

# %% [markdown]
# #### 14.XY

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def bar_reverse_axis():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(Faker.choose())
    bar.add_yaxis('A', Faker.values())
    bar.add_yaxis('B', Faker.values())
    # x,y
    bar.reversal_axis()
    return bar


chart = bar_reverse_axis()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a597b66111df4081abb4210c48934e82" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a597b66111df4081abb4210c48934e82 = echarts.init(
#                     document.getElementById('a597b66111df4081abb4210c48934e82'), 'light', {renderer: 'canvas'});
#                 var option_a597b66111df4081abb4210c48934e82 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "legendHoverLink": true,
#             "data": [
#                 135,
#                 141,
#                 42,
#                 104,
#                 117,
#                 85,
#                 148
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "legendHoverLink": true,
#             "data": [
#                 78,
#                 139,
#                 25,
#                 121,
#                 102,
#                 114,
#                 96
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ]
# };
#                 chart_a597b66111df4081abb4210c48934e82.setOption(option_a597b66111df4081abb4210c48934e82);
#         });
#     </script>

# %% [markdown]
# #### 15.Effectiveness
#
# * Effectiveness；
# * Effectiveness：https://echarts.apache.org/examples/zh/editor.html?c=line-easing

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker

"""
Effectiveness：https://echarts.apache.org/examples/zh/editor.html?c=line-easing
"""


def bar_with_animation():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px',
                                      animation_opts=opts.AnimationOpts(animation_delay=1000,   # hour
                                                                        animation_easing='bounceIn')
                                      )
              )
    bar.add_xaxis(Faker.choose())
    bar.add_yaxis('A', Faker.values())
    bar.add_yaxis('B', Faker.values())
    return bar


chart = bar_with_animation()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7bf21221f49440098b314a83292aecea" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7bf21221f49440098b314a83292aecea = echarts.init(
#                     document.getElementById('7bf21221f49440098b314a83292aecea'), 'light', {renderer: 'canvas'});
#                 var option_7bf21221f49440098b314a83292aecea = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "bounceIn",
#     "animationDelay": 1000,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "legendHoverLink": true,
#             "data": [
#                 76,
#                 74,
#                 53,
#                 137,
#                 133,
#                 40,
#                 90
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "legendHoverLink": true,
#             "data": [
#                 80,
#                 77,
#                 61,
#                 107,
#                 83,
#                 110,
#                 42
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_7bf21221f49440098b314a83292aecea.setOption(option_7bf21221f49440098b314a83292aecea);
#         });
#     </script>

# %% [markdown]
# #### 15.

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def bar_with_visualmap_color():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(Faker.choose())
    bar.add_yaxis('A', Faker.values())
    bar.add_yaxis('B', Faker.values())
    # ，through Colordata，0-100，through min_ and max_
    bar.set_global_opts(visualmap_opts=opts.VisualMapOpts())
    return bar


chart = bar_with_visualmap_color()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="cfc2e594b11e47cb8940219455bf46a6" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_cfc2e594b11e47cb8940219455bf46a6 = echarts.init(
#                     document.getElementById('cfc2e594b11e47cb8940219455bf46a6'), 'light', {renderer: 'canvas'});
#                 var option_cfc2e594b11e47cb8940219455bf46a6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "legendHoverLink": true,
#             "data": [
#                 29,
#                 46,
#                 59,
#                 83,
#                 104,
#                 93,
#                 55
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "legendHoverLink": true,
#             "data": [
#                 20,
#                 142,
#                 109,
#                 69,
#                 73,
#                 91,
#                 126
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_cfc2e594b11e47cb8940219455bf46a6.setOption(option_cfc2e594b11e47cb8940219455bf46a6);
#         });
#     </script>

# %% [markdown]
# #### 16.()

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker
from pyecharts.commons.utils import JsCode

color_js = """
            new echarts.graphic.LinearGradient(
                                0, 
                                1, 
                                0, 
                                0,
                                [{offset: 0, color: '#008B8B'}, 
                                 {offset: 1, color: '#FF6347'}], 
                                false)
           """


def bar_with_linear_gradient_color():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(Faker.choose())
    bar.add_yaxis('', Faker.values(),
                  # using JsCode
                  itemstyle_opts=opts.ItemStyleOpts(color=JsCode(color_js)))

    return bar


chart = bar_with_linear_gradient_color()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="34733daaf9fb401cad884d93283c3c38" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_34733daaf9fb401cad884d93283c3c38 = echarts.init(
#                     document.getElementById('34733daaf9fb401cad884d93283c3c38'), 'light', {renderer: 'canvas'});
#                 var option_34733daaf9fb401cad884d93283c3c38 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 93,
#                 47,
#                 76,
#                 34,
#                 104,
#                 64,
#                 93
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "color":             new echarts.graphic.LinearGradient(                                0,                                 1,                                 0,                                 0,                                [{offset: 0, color: '#008B8B'},                                  {offset: 1, color: '#FF6347'}],                                 false)
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_34733daaf9fb401cad884d93283c3c38.setOption(option_34733daaf9fb401cad884d93283c3c38);
#         });
#     </script>

# %% [markdown]
# #### 17.()

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker
from pyecharts.commons.utils import JsCode

color_js = """new echarts.graphic.RadialGradient(
                    0.4, 0.3, 1,
                    [{offset: 0,
                      color: '#F8F8FF'},
                     {offset: 1,
                      color: '#00BFFF'}
                      ])"""


def scatter_with_radial_gradient_color():
    scatter = Scatter(init_opts=opts.InitOpts(theme='light',
                                              width='1000px',
                                              height='600px'))
    scatter.add_xaxis(Faker.choose())

    scatter.add_yaxis("", Faker.values(),
                      symbol_size=50,
                      # 
                      itemstyle_opts=opts.ItemStyleOpts(color=JsCode(color_js)))
    return scatter


chart = scatter_with_radial_gradient_color()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1ceb726c8e18483bac571a3db01d7bd4" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1ceb726c8e18483bac571a3db01d7bd4 = echarts.init(
#                     document.getElementById('1ceb726c8e18483bac571a3db01d7bd4'), 'light', {renderer: 'canvas'});
#                 var option_1ceb726c8e18483bac571a3db01d7bd4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 50,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     125
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     73
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     118
#                 ],
#                 [
#                     "\u5468\u56db",
#                     127
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     40
#                 ],
#                 [
#                     "\u5468\u516d",
#                     114
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     40
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "color": new echarts.graphic.RadialGradient(                    0.4, 0.3, 1,                    [{offset: 0,                      color: '#F8F8FF'},                     {offset: 1,                      color: '#00BFFF'}                      ])
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_1ceb726c8e18483bac571a3db01d7bd4.setOption(option_1ceb726c8e18483bac571a3db01d7bd4);
#         });
#     </script>

# %% [markdown]
# #### 18.minute

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def bar_with_custom_splitline():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(Faker.choose())
    bar.add_yaxis('A', Faker.values())
    bar.add_yaxis('B', Faker.values())
    # minute
    bar.set_global_opts(yaxis_opts=opts.AxisOpts(
        splitline_opts=opts.SplitLineOpts(is_show=True,
                                          linestyle_opts=opts.LineStyleOpts(type_='dotted'))))
    return bar


chart = bar_with_custom_splitline()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a68c9e3e29454f449ce925435ab3304e" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a68c9e3e29454f449ce925435ab3304e = echarts.init(
#                     document.getElementById('a68c9e3e29454f449ce925435ab3304e'), 'light', {renderer: 'canvas'});
#                 var option_a68c9e3e29454f449ce925435ab3304e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "legendHoverLink": true,
#             "data": [
#                 47,
#                 129,
#                 53,
#                 84,
#                 78,
#                 84,
#                 84
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "legendHoverLink": true,
#             "data": [
#                 150,
#                 114,
#                 91,
#                 56,
#                 127,
#                 40,
#                 42
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "dotted"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_a68c9e3e29454f449ce925435ab3304e.setOption(option_a68c9e3e29454f449ce925435ab3304e);
#         });
#     </script>

# %% [markdown]
# #### 19.minute

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def bar_with_custom_splitarea():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(Faker.choose())
    bar.add_yaxis('A', Faker.values())
    bar.add_yaxis('B', Faker.values())
    # minute
    bar.set_global_opts(yaxis_opts=opts.AxisOpts(
        splitarea_opts=opts.SplitAreaOpts(is_show=True,
                                          areastyle_opts=opts.AreaStyleOpts(opacity=1))))
    return bar


chart = bar_with_custom_splitarea()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3dce2a19c10d47368a3885571e9cbc2d" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3dce2a19c10d47368a3885571e9cbc2d = echarts.init(
#                     document.getElementById('3dce2a19c10d47368a3885571e9cbc2d'), 'light', {renderer: 'canvas'});
#                 var option_3dce2a19c10d47368a3885571e9cbc2d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "legendHoverLink": true,
#             "data": [
#                 65,
#                 81,
#                 61,
#                 150,
#                 58,
#                 80,
#                 93
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "legendHoverLink": true,
#             "data": [
#                 72,
#                 73,
#                 111,
#                 94,
#                 82,
#                 76,
#                 77
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "splitArea": {
#                 "show": true,
#                 "areaStyle": {
#                     "opacity": 1
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_3dce2a19c10d47368a3885571e9cbc2d.setOption(option_3dce2a19c10d47368a3885571e9cbc2d);
#         });
#     </script>

# %% [markdown]
# #### 20.through

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def bar_with_dict_config():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(Faker.choose())
    bar.add_yaxis('', Faker.values())
    # through itemstyle
    bar.set_series_opts(itemstyle_opts=dict(color='#008B8B', opacity=0.8))
    return bar


chart = bar_with_dict_config()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8b981035591f4d76a5671a283edd5770" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8b981035591f4d76a5671a283edd5770 = echarts.init(
#                     document.getElementById('8b981035591f4d76a5671a283edd5770'), 'light', {renderer: 'canvas'});
#                 var option_8b981035591f4d76a5671a283edd5770 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "legendHoverLink": true,
#             "data": [
#                 140,
#                 39,
#                 35,
#                 51,
#                 81,
#                 80,
#                 132
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "itemStyle": {
#                 "color": "#008B8B",
#                 "opacity": 0.8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_8b981035591f4d76a5671a283edd5770.setOption(option_8b981035591f4d76a5671a283edd5770);
#         });
#     </script>

# %% [markdown]
# #### 21.Area
# * implement yes****；

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data = ["2020/10/{}".format(i + 1) for i in range(30)]

# data
y_data = [i + random.randint(10, 20) for i in range(len(x_data))]


def line_with_area():
    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='1000px',
                                        height='600px'))
    line.add_xaxis(x_data)
    line.add_yaxis('', y_data)
    # opacity 0，
    line.set_series_opts(areastyle_opts=opts.AreaStyleOpts(opacity=0.5))

    return line


chart = line_with_area()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="eca658a8d14f41d380f91cf976c3b157" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_eca658a8d14f41d380f91cf976c3b157 = echarts.init(
#                     document.getElementById('eca658a8d14f41d380f91cf976c3b157'), 'light', {renderer: 'canvas'});
#                 var option_eca658a8d14f41d380f91cf976c3b157 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020/10/1",
#                     17
#                 ],
#                 [
#                     "2020/10/2",
#                     15
#                 ],
#                 [
#                     "2020/10/3",
#                     22
#                 ],
#                 [
#                     "2020/10/4",
#                     16
#                 ],
#                 [
#                     "2020/10/5",
#                     17
#                 ],
#                 [
#                     "2020/10/6",
#                     17
#                 ],
#                 [
#                     "2020/10/7",
#                     24
#                 ],
#                 [
#                     "2020/10/8",
#                     18
#                 ],
#                 [
#                     "2020/10/9",
#                     28
#                 ],
#                 [
#                     "2020/10/10",
#                     23
#                 ],
#                 [
#                     "2020/10/11",
#                     20
#                 ],
#                 [
#                     "2020/10/12",
#                     26
#                 ],
#                 [
#                     "2020/10/13",
#                     30
#                 ],
#                 [
#                     "2020/10/14",
#                     27
#                 ],
#                 [
#                     "2020/10/15",
#                     27
#                 ],
#                 [
#                     "2020/10/16",
#                     25
#                 ],
#                 [
#                     "2020/10/17",
#                     29
#                 ],
#                 [
#                     "2020/10/18",
#                     34
#                 ],
#                 [
#                     "2020/10/19",
#                     36
#                 ],
#                 [
#                     "2020/10/20",
#                     38
#                 ],
#                 [
#                     "2020/10/21",
#                     36
#                 ],
#                 [
#                     "2020/10/22",
#                     33
#                 ],
#                 [
#                     "2020/10/23",
#                     42
#                 ],
#                 [
#                     "2020/10/24",
#                     36
#                 ],
#                 [
#                     "2020/10/25",
#                     38
#                 ],
#                 [
#                     "2020/10/26",
#                     45
#                 ],
#                 [
#                     "2020/10/27",
#                     45
#                 ],
#                 [
#                     "2020/10/28",
#                     45
#                 ],
#                 [
#                     "2020/10/29",
#                     48
#                 ],
#                 [
#                     "2020/10/30",
#                     46
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020/10/1",
#                 "2020/10/2",
#                 "2020/10/3",
#                 "2020/10/4",
#                 "2020/10/5",
#                 "2020/10/6",
#                 "2020/10/7",
#                 "2020/10/8",
#                 "2020/10/9",
#                 "2020/10/10",
#                 "2020/10/11",
#                 "2020/10/12",
#                 "2020/10/13",
#                 "2020/10/14",
#                 "2020/10/15",
#                 "2020/10/16",
#                 "2020/10/17",
#                 "2020/10/18",
#                 "2020/10/19",
#                 "2020/10/20",
#                 "2020/10/21",
#                 "2020/10/22",
#                 "2020/10/23",
#                 "2020/10/24",
#                 "2020/10/25",
#                 "2020/10/26",
#                 "2020/10/27",
#                 "2020/10/28",
#                 "2020/10/29",
#                 "2020/10/30"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_eca658a8d14f41d380f91cf976c3b157.setOption(option_eca658a8d14f41d380f91cf976c3b157);
#         });
#     </script>

# %% [markdown]
# #### 22.Area

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def line_stack_area():
    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='1000px',
                                        height='600px'))
    line.add_xaxis(Faker.choose())
    line.add_yaxis('A',
                   Faker.values(),
                   stack='stack')
    line.add_yaxis('B',
                   Faker.values(),
                   stack='stack')
    line.add_yaxis('C',
                   Faker.values(),
                   stack='stack')
    # opacity 0，
    line.set_series_opts(areastyle_opts=opts.AreaStyleOpts(opacity=0.5))

    return line


chart = line_stack_area()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7d9fbc54d91f4172ba9319755bcf9a27" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7d9fbc54d91f4172ba9319755bcf9a27 = echarts.init(
#                     document.getElementById('7d9fbc54d91f4172ba9319755bcf9a27'), 'light', {renderer: 'canvas'});
#                 var option_7d9fbc54d91f4172ba9319755bcf9a27 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "A",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stack": "stack",
#             "data": [
#                 [
#                     "\u8349\u8393",
#                     108
#                 ],
#                 [
#                     "\u8292\u679c",
#                     111
#                 ],
#                 [
#                     "\u8461\u8404",
#                     135
#                 ],
#                 [
#                     "\u96ea\u68a8",
#                     138
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     45
#                 ],
#                 [
#                     "\u67e0\u6aac",
#                     40
#                 ],
#                 [
#                     "\u8f66\u5398\u5b50",
#                     147
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "B",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stack": "stack",
#             "data": [
#                 [
#                     "\u8349\u8393",
#                     62
#                 ],
#                 [
#                     "\u8292\u679c",
#                     98
#                 ],
#                 [
#                     "\u8461\u8404",
#                     76
#                 ],
#                 [
#                     "\u96ea\u68a8",
#                     48
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     73
#                 ],
#                 [
#                     "\u67e0\u6aac",
#                     136
#                 ],
#                 [
#                     "\u8f66\u5398\u5b50",
#                     52
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "C",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stack": "stack",
#             "data": [
#                 [
#                     "\u8349\u8393",
#                     111
#                 ],
#                 [
#                     "\u8292\u679c",
#                     99
#                 ],
#                 [
#                     "\u8461\u8404",
#                     122
#                 ],
#                 [
#                     "\u96ea\u68a8",
#                     46
#                 ],
#                 [
#                     "\u897f\u74dc",
#                     50
#                 ],
#                 [
#                     "\u67e0\u6aac",
#                     45
#                 ],
#                 [
#                     "\u8f66\u5398\u5b50",
#                     106
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B",
#                 "C"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true,
#                 "C": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,

# %% [markdown]
# #### 23.（LineStyleOpts）

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def line_with_custom_linestyle():
    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='1000px',
                                        height='600px'))
    line.add_xaxis(Faker.choose())
    line.add_yaxis('1',
                   Faker.values(),
                   linestyle_opts=opts.LineStyleOpts(width=5,
                                                     curve=0,
                                                     opacity=0.7,
                                                     type_='solid',
                                                     color='red')
                   )
    line.add_yaxis('2',
                   Faker.values(),
                   linestyle_opts=opts.LineStyleOpts(width=3,
                                                     curve=0.5,
                                                     opacity=0.9,
                                                     type_='dashed',
                                                     color='yellow')
                   )
    line.add_yaxis('3',
                   Faker.values(),
                   linestyle_opts=opts.LineStyleOpts(width=1,
                                                     curve=1,
                                                     opacity=0.5,
                                                     type_='dotted',
                                                     color='green')
                   )
    return line


chart = line_with_custom_linestyle()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8d667997fa8945b198d1accce9e45a1e" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8d667997fa8945b198d1accce9e45a1e = echarts.init(
#                     document.getElementById('8d667997fa8945b198d1accce9e45a1e'), 'light', {renderer: 'canvas'});
#                 var option_8d667997fa8945b198d1accce9e45a1e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u6837\u5f0f1",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u54c8\u58eb\u5947",
#                     122
#                 ],
#                 [
#                     "\u8428\u6469\u8036",
#                     109
#                 ],
#                 [
#                     "\u6cf0\u8fea",
#                     147
#                 ],
#                 [
#                     "\u91d1\u6bdb",
#                     129
#                 ],
#                 [
#                     "\u7267\u7f8a\u72ac",
#                     112
#                 ],
#                 [
#                     "\u5409\u5a03\u5a03",
#                     28
#                 ],
#                 [
#                     "\u67ef\u57fa",
#                     126
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 5,
#                 "opacity": 0.7,
#                 "curveness": 0,
#                 "type": "solid",
#                 "color": "red"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u6837\u5f0f2",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u54c8\u58eb\u5947",
#                     74
#                 ],
#                 [
#                     "\u8428\u6469\u8036",
#                     142
#                 ],
#                 [
#                     "\u6cf0\u8fea",
#                     110
#                 ],
#                 [
#                     "\u91d1\u6bdb",
#                     31
#                 ],
#                 [
#                     "\u7267\u7f8a\u72ac",
#                     82
#                 ],
#                 [
#                     "\u5409\u5a03\u5a03",
#                     100
#                 ],
#                 [
#                     "\u67ef\u57fa",
#                     129
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 3,
#                 "opacity": 0.9,
#                 "curveness": 0.5,
#                 "type": "dashed",
#                 "color": "yellow"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u6837\u5f0f3",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u54c8\u58eb\u5947",
#                     33
#                 ],
#                 [
#                     "\u8428\u6469\u8036",
#                     22
#                 ],
#                 [
#                     "\u6cf0\u8fea",
#                     53
#                 ],
#                 [
#                     "\u91d1\u6bdb",
#                     77
#                 ],
#                 [
#                     "\u7267\u7f8a\u72ac",
#                     125
#                 ],
#                 [
#                     "\u5409\u5a03\u5a03",
#                     37
#                 ],
#                 [
#                     "\u67ef\u57fa",
#                     44
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 0.5,
#                 "curveness": 1,
#                 "type": "dotted",
#                 "color": "green"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6837\u5f0f1",
#                 "\u6837\u5f0f2",
#                 "\u6837\u5f0f3"
#             ],
#             "selected": {
#                 "\u6837\u5f0f1": true,
#                 "\u6837\u5f0f2": true,
#                 "\u6837\u5f0f3": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_8d667997fa8945b198d1accce9e45a1e.setOption(option_8d667997fa8945b198d1accce9e45a1e);
#         });
#     </script>

# %% [markdown]
# #### 24. Effectiveness
#
# * `linestyle_opts`parameterEffectiveness，through dict`shadowOffsetX`parameterimplement ；

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

line_style = {
    'normal': {
        'width': 4,  # 
        'shadowColor': 'rgba(155, 18, 184, .3)',  # Color
        'shadowBlur': 10,  # 
        'shadowOffsetY': 10,  # Y
        'shadowOffsetX': 10,  # x
        'curve': 0.5  # ，1indicates
    }
}

x_data = ["2020/10/{}".format(i + 1) for i in range(30)]

# data
y_data_1 = [i + random.randint(10, 20) for i in range(len(x_data))]
y_data_2 = [i + random.randint(15, 25) for i in range(len(x_data))]


def line_with_shadow():
    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='1000px',
                                        height='600px'))
    line.add_xaxis(x_data)
    line.add_yaxis("Android",
                   y_data_1,
                   is_symbol_show=False,
                   is_smooth=True,
                   # parameter
                   linestyle_opts=line_style)
    line.add_yaxis("IOS",
                   y_data_2,
                   is_symbol_show=False,
                   is_smooth=True,
                   # parameter
                   linestyle_opts=line_style)
    line.set_global_opts(title_opts=opts.TitleOpts(title="day"))
    return line


chart = line_with_shadow()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2a9c43fa59084f85b0f115bc574a5241" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2a9c43fa59084f85b0f115bc574a5241 = echarts.init(
#                     document.getElementById('2a9c43fa59084f85b0f115bc574a5241'), 'light', {renderer: 'canvas'});
#                 var option_2a9c43fa59084f85b0f115bc574a5241 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "Android",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": false,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020/10/1",
#                     14
#                 ],
#                 [
#                     "2020/10/2",
#                     12
#                 ],
#                 [
#                     "2020/10/3",
#                     18
#                 ],
#                 [
#                     "2020/10/4",
#                     22
#                 ],
#                 [
#                     "2020/10/5",
#                     23
#                 ],
#                 [
#                     "2020/10/6",
#                     20
#                 ],
#                 [
#                     "2020/10/7",
#                     24
#                 ],
#                 [
#                     "2020/10/8",
#                     25
#                 ],
#                 [
#                     "2020/10/9",
#                     18
#                 ],
#                 [
#                     "2020/10/10",
#                     23
#                 ],
#                 [
#                     "2020/10/11",
#                     24
#                 ],
#                 [
#                     "2020/10/12",
#                     27
#                 ],
#                 [
#                     "2020/10/13",
#                     32
#                 ],
#                 [
#                     "2020/10/14",
#                     30
#                 ],
#                 [
#                     "2020/10/15",
#                     26
#                 ],
#                 [
#                     "2020/10/16",
#                     31
#                 ],
#                 [
#                     "2020/10/17",
#                     34
#                 ],
#                 [
#                     "2020/10/18",
#                     32
#                 ],
#                 [
#                     "2020/10/19",
#                     34
#                 ],
#                 [
#                     "2020/10/20",
#                     31
#                 ],
#                 [
#                     "2020/10/21",
#                     35
#                 ],
#                 [
#                     "2020/10/22",
#                     31
#                 ],
#                 [
#                     "2020/10/23",
#                     39
#                 ],
#                 [
#                     "2020/10/24",
#                     36
#                 ],
#                 [
#                     "2020/10/25",
#                     41
#                 ],
#                 [
#                     "2020/10/26",
#                     37
#                 ],
#                 [
#                     "2020/10/27",
#                     39
#                 ],
#                 [
#                     "2020/10/28",
#                     46
#                 ],
#                 [
#                     "2020/10/29",
#                     38
#                 ],
#                 [
#                     "2020/10/30",
#                     49
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "normal": {
#                     "width": 4,
#                     "shadowColor": "rgba(155, 18, 184, .3)",
#                     "shadowBlur": 10,
#                     "shadowOffsetY": 10,
#                     "shadowOffsetX": 10,
#                     "curve": 0.5
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "IOS",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": false,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020/10/1",
#                     15
#                 ],
#                 [
#                     "2020/10/2",
#                     20
#                 ],
#                 [
#                     "2020/10/3",
#                     18
#                 ],
#                 [
#                     "2020/10/4",
#                     20
#                 ],
#                 [
#                     "2020/10/5",
#                     23
#                 ],
#                 [
#                     "2020/10/6",
#                     23
#                 ],
#                 [
#                     "2020/10/7",
#                     27
#                 ],
#                 [
#                     "2020/10/8",
#                     32
#                 ],
#                 [
#                     "2020/10/9",
#                     26
#                 ],
#                 [
#                     "2020/10/10",
#                     30
#                 ],
#                 [
#                     "2020/10/11",
#                     29
#                 ],
#                 [
#                     "2020/10/12",
#                     33
#                 ],
#                 [
#                     "2020/10/13",
#                     34
#                 ],
#                 [
#                     "2020/10/14",
#                     28
#                 ],
#                 [
#                     "2020/10/15",
#                     38
#                 ],
#                 [
#                     "2020/10/16",
#                     30
#                 ],
#                 [
#                     "2020/10/17",
#                     41
#                 ],
#                 [
#                     "2020/10/18",
#                     34
#                 ],
#                 [
#                     "2020/10/19",
#                     33
#                 ],
#                 [
#                     "2020/10/20",
#                     41
#                 ],
#                 [
#                     "2020/10/21",
#                     41
#                 ],
#                 [
#                     "2020/10/22",
#                     37
#                 ],
#                 [
#                     "2020/10/23",
#                     47
#                 ],
#                 [
#                     "2020/10/24",
#                     39
#                 ],
#                 [
#                     "2020/10/25",
#                     43
#                 ],
#                 [
#                     "2020/10/26",
#                     49
#                 ],
#                 [
#                     "2020/10/27",
#                     44
#                 ],
#                 [
#                     "2020/10/28",
#                     49
#                 ],
#                 [
#                     "2020/10/29",
#                     45
#                 ],
#                 [
#                     "2020/10/30",
#                     49
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "normal": {
#                     "width": 4,

# %% [markdown]
# #### 25.processing

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def line_with_smooth_connect():
    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='1000px',
                                        height='600px'))
    line.add_xaxis(Faker.choose())
    # is_smooth=True
    line.add_yaxis('', Faker.values(), is_smooth=True)
    line.add_yaxis('', Faker.values(), is_smooth=False)

    return line


chart = line_with_smooth_connect()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="733b2c550a7a41cb8304a3bcd02bda30" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_733b2c550a7a41cb8304a3bcd02bda30 = echarts.init(
#                     document.getElementById('733b2c550a7a41cb8304a3bcd02bda30'), 'light', {renderer: 'canvas'});
#                 var option_733b2c550a7a41cb8304a3bcd02bda30 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5e73\u6ed1\u66f2\u7ebf",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     134
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     88
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     77
#                 ],
#                 [
#                     "\u5468\u56db",
#                     126
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     91
#                 ],
#                 [
#                     "\u5468\u516d",
#                     52
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     77
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u76f4\u7ebf",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     47
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     58
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     40
#                 ],
#                 [
#                     "\u5468\u56db",
#                     43
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     129
#                 ],
#                 [
#                     "\u5468\u516d",
#                     123
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     111
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e73\u6ed1\u66f2\u7ebf",
#                 "\u76f4\u7ebf"
#             ],
#             "selected": {
#                 "\u5e73\u6ed1\u66f2\u7ebf": true,
#                 "\u76f4\u7ebf": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_733b2c550a7a41cb8304a3bcd02bda30.setOption(option_733b2c550a7a41cb8304a3bcd02bda30);
#         });
#     </script>

# %% [markdown]
# #### 26. (max，mean)

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def bar_with_guide_line():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    bar.add_xaxis(Faker.choose())
    bar.add_yaxis('A', Faker.values())
    bar.add_yaxis('B', Faker.values())
    # 
    bar.set_series_opts(
        markline_opts=opts.MarkLineOpts(
            data=[
                opts.MarkLineItem(type_="min", name="min"),
                opts.MarkLineItem(type_="max", name="max"),
                opts.MarkLineItem(type_="average", name="mean"),
            ]
        )
    )

    return bar


chart = bar_with_guide_line()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d00a9ea94ef54c94a1f731c8936f4f58" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d00a9ea94ef54c94a1f731c8936f4f58 = echarts.init(
#                     document.getElementById('d00a9ea94ef54c94a1f731c8936f4f58'), 'light', {renderer: 'canvas'});
#                 var option_d00a9ea94ef54c94a1f731c8936f4f58 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "legendHoverLink": true,
#             "data": [
#                 56,
#                 81,
#                 119,
#                 100,
#                 49,
#                 54,
#                 135
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "legendHoverLink": true,
#             "data": [
#                 98,
#                 46,
#                 59,
#                 50,
#                 56,
#                 119,
#                 101
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u6700\u5c0f\u503c",
#                         "type": "min"
#                     },
#                     {
#                         "name": "\u6700\u5927\u503c",
#                         "type": "max"
#                     },
#                     {
#                         "name": "\u5e73\u5747\u503c",
#                         "type": "average"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_d00a9ea94ef54c94a1f731c8936f4f58.setOption(option_d00a9ea94ef54c94a1f731c8936f4f58);
#         });
#     </script>

# %% [markdown]
# #### 27.

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data = ["2020/10/{}".format(i + 1) for i in range(30)]

# data
y_data = [i + random.randint(10, 20) for i in range(len(x_data))]


def line_with_custom_mark_point():
    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='1000px',
                                        height='600px'))
    line.add_xaxis(x_data)
    line.add_yaxis('', y_data)
    # 
    line.set_series_opts(
        markpoint_opts=opts.MarkPointOpts(
            data=[opts.MarkPointItem(name="", coord=[x_data[2], y_data[2]], value=y_data[2])]
        )
    )

    return line


chart = line_with_custom_mark_point()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="43f1ad779f6e4dd0b26770e1e7121450" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_43f1ad779f6e4dd0b26770e1e7121450 = echarts.init(
#                     document.getElementById('43f1ad779f6e4dd0b26770e1e7121450'), 'light', {renderer: 'canvas'});
#                 var option_43f1ad779f6e4dd0b26770e1e7121450 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020/10/1",
#                     19
#                 ],
#                 [
#                     "2020/10/2",
#                     15
#                 ],
#                 [
#                     "2020/10/3",
#                     18
#                 ],
#                 [
#                     "2020/10/4",
#                     22
#                 ],
#                 [
#                     "2020/10/5",
#                     21
#                 ],
#                 [
#                     "2020/10/6",
#                     18
#                 ],
#                 [
#                     "2020/10/7",
#                     18
#                 ],
#                 [
#                     "2020/10/8",
#                     24
#                 ],
#                 [
#                     "2020/10/9",
#                     20
#                 ],
#                 [
#                     "2020/10/10",
#                     20
#                 ],
#                 [
#                     "2020/10/11",
#                     21
#                 ],
#                 [
#                     "2020/10/12",
#                     21
#                 ],
#                 [
#                     "2020/10/13",
#                     29
#                 ],
#                 [
#                     "2020/10/14",
#                     26
#                 ],
#                 [
#                     "2020/10/15",
#                     34
#                 ],
#                 [
#                     "2020/10/16",
#                     25
#                 ],
#                 [
#                     "2020/10/17",
#                     26
#                 ],
#                 [
#                     "2020/10/18",
#                     31
#                 ],
#                 [
#                     "2020/10/19",
#                     35
#                 ],
#                 [
#                     "2020/10/20",
#                     37
#                 ],
#                 [
#                     "2020/10/21",
#                     32
#                 ],
#                 [
#                     "2020/10/22",
#                     39
#                 ],
#                 [
#                     "2020/10/23",
#                     36
#                 ],
#                 [
#                     "2020/10/24",
#                     39
#                 ],
#                 [
#                     "2020/10/25",
#                     41
#                 ],
#                 [
#                     "2020/10/26",
#                     41
#                 ],
#                 [
#                     "2020/10/27",
#                     40
#                 ],
#                 [
#                     "2020/10/28",
#                     40
#                 ],
#                 [
#                     "2020/10/29",
#                     45
#                 ],
#                 [
#                     "2020/10/30",
#                     39
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "name": "\u81ea\u5b9a\u4e49\u6807\u8bb0\u70b9",
#                         "coord": [
#                             "2020/10/3",
#                             18
#                         ],
#                         "value": 18
#                     }
#                 ]
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020/10/1",
#                 "2020/10/2",
#                 "2020/10/3",
#                 "2020/10/4",
#                 "2020/10/5",
#                 "2020/10/6",
#                 "2020/10/7",
#                 "2020/10/8",
#                 "2020/10/9",
#                 "2020/10/10",
#                 "2020/10/11",
#                 "2020/10/12",
#                 "2020/10/13",
#                 "2020/10/14",
#                 "2020/10/15",
#                 "2020/10/16",
#                 "2020/10/17",
#                 "2020/10/18",
#                 "2020/10/19",
#                 "2020/10/20",
#                 "2020/10/21",
#                 "2020/10/22",
#                 "2020/10/23",
#                 "2020/10/24",
#                 "2020/10/25",
#                 "2020/10/26",
#                 "2020/10/27",
#                 "2020/10/28",
#                 "2020/10/29",
#                 "2020/10/30"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }

# %% [markdown]
# #### 28.

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data = ["2020/10/{}".format(i + 1) for i in range(30)]

# data
y_data = [i + random.randint(10, 20) for i in range(len(x_data))]


def line_with_mark_area():
    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='1000px',
                                        height='600px'))
    line.add_xaxis(x_data)
    line.add_yaxis('', y_data)
    # 
    line.set_series_opts(
        markarea_opts=opts.MarkAreaOpts(
            data=[
                opts.MarkAreaItem(name="", x=("2020/10/1", "2020/10/8"))
            ]
        )
    )

    return line


chart = line_with_mark_area()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5e8d3b2bd7824698b1314c1e84ad9c2b" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5e8d3b2bd7824698b1314c1e84ad9c2b = echarts.init(
#                     document.getElementById('5e8d3b2bd7824698b1314c1e84ad9c2b'), 'light', {renderer: 'canvas'});
#                 var option_5e8d3b2bd7824698b1314c1e84ad9c2b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2020/10/1",
#                     17
#                 ],
#                 [
#                     "2020/10/2",
#                     11
#                 ],
#                 [
#                     "2020/10/3",
#                     13
#                 ],
#                 [
#                     "2020/10/4",
#                     15
#                 ],
#                 [
#                     "2020/10/5",
#                     22
#                 ],
#                 [
#                     "2020/10/6",
#                     24
#                 ],
#                 [
#                     "2020/10/7",
#                     18
#                 ],
#                 [
#                     "2020/10/8",
#                     20
#                 ],
#                 [
#                     "2020/10/9",
#                     21
#                 ],
#                 [
#                     "2020/10/10",
#                     24
#                 ],
#                 [
#                     "2020/10/11",
#                     21
#                 ],
#                 [
#                     "2020/10/12",
#                     27
#                 ],
#                 [
#                     "2020/10/13",
#                     24
#                 ],
#                 [
#                     "2020/10/14",
#                     23
#                 ],
#                 [
#                     "2020/10/15",
#                     26
#                 ],
#                 [
#                     "2020/10/16",
#                     32
#                 ],
#                 [
#                     "2020/10/17",
#                     36
#                 ],
#                 [
#                     "2020/10/18",
#                     36
#                 ],
#                 [
#                     "2020/10/19",
#                     29
#                 ],
#                 [
#                     "2020/10/20",
#                     36
#                 ],
#                 [
#                     "2020/10/21",
#                     37
#                 ],
#                 [
#                     "2020/10/22",
#                     39
#                 ],
#                 [
#                     "2020/10/23",
#                     32
#                 ],
#                 [
#                     "2020/10/24",
#                     34
#                 ],
#                 [
#                     "2020/10/25",
#                     40
#                 ],
#                 [
#                     "2020/10/26",
#                     39
#                 ],
#                 [
#                     "2020/10/27",
#                     39
#                 ],
#                 [
#                     "2020/10/28",
#                     44
#                 ],
#                 [
#                     "2020/10/29",
#                     42
#                 ],
#                 [
#                     "2020/10/30",
#                     47
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0,
#             "markArea": {
#                 "silent": false,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 },
#                 "data": [
#                     [
#                         {
#                             "name": "\u9ec4\u91d1\u5468",
#                             "xAxis": "2020/10/1"
#                         },
#                         {
#                             "xAxis": "2020/10/8"
#                         }
#                     ]
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020/10/1",
#                 "2020/10/2",
#                 "2020/10/3",
#                 "2020/10/4",
#                 "2020/10/5",
#                 "2020/10/6",
#                 "2020/10/7",
#                 "2020/10/8",
#                 "2020/10/9",
#                 "2020/10/10",
#                 "2020/10/11",
#                 "2020/10/12",
#                 "2020/10/13",
#                 "2020/10/14",
#                 "2020/10/15",
#                 "2020/10/16",
#                 "2020/10/17",
#                 "2020/10/18",
#                 "2020/10/19",
#                 "2020/10/20",
#                 "2020/10/21",
#                 "2020/10/22",
#                 "2020/10/23",
#                 "2020/10/24",
#                 "2020/10/25",
#                 "2020/10/26",
#                 "2020/10/27",
#                 "2020/10/28",
#                 "2020/10/29",
#                 "2020/10/30"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };

# %% [markdown]
# #### 29.minute

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.commons.utils import JsCode


x_data = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
y_data = [0.98, 0.89, 0.92, 1.07, 0.81, 1.23]

js = """function (param) {return param.name +':'+ Math.floor(param.value[1])+'%';}"""


def line_with_per_show():
    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='1000px',
                                        height='600px'))
    line.add_xaxis(x_data)
    # datahour100
    line.add_yaxis('', [round(v * 100, 0) for v in y_data])
    # js%
    line.set_series_opts(label_opts=opts.LabelOpts(is_show=True,
                                                   formatter=JsCode(js)))

    return line


chart = line_with_per_show()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5f1199559ef0455287f9e8c48a87ae85" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5f1199559ef0455287f9e8c48a87ae85 = echarts.init(
#                     document.getElementById('5f1199559ef0455287f9e8c48a87ae85'), 'light', {renderer: 'canvas'});
#                 var option_5f1199559ef0455287f9e8c48a87ae85 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "Apple",
#                     98.0
#                 ],
#                 [
#                     "Huawei",
#                     89.0
#                 ],
#                 [
#                     "Xiaomi",
#                     92.0
#                 ],
#                 [
#                     "Oppo",
#                     107.0
#                 ],
#                 [
#                     "Vivo",
#                     81.0
#                 ],
#                 [
#                     "Meizu",
#                     123.0
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": function (param) {return param.name +':'+ Math.floor(param.value[1])+'%';}
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Apple",
#                 "Huawei",
#                 "Xiaomi",
#                 "Oppo",
#                 "Vivo",
#                 "Meizu"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_5f1199559ef0455287f9e8c48a87ae85.setOption(option_5f1199559ef0455287f9e8c48a87ae85);
#         });
#     </script>

# %% [markdown]
# #### 30.

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def pictorialbar_with_custom_symbol():
    pictorialbar = PictorialBar(init_opts=opts.InitOpts(theme='light',
                                                        width='1000px',
                                                        height='600px'))
    pictorialbar.add_xaxis(Faker.choose())
    pictorialbar.add_yaxis('A',
                           Faker.values(),
                           symbol_size=20,
                           # 
                           symbol='path://M100,0 L41.22,180.90 L195.10,69.09 L4.89,69.09 L158.77,180.90 z',
                           symbol_repeat="fixed",
                           is_symbol_clip=True
                           )

    return pictorialbar


chart = pictorialbar_with_custom_symbol()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b13ac4806c064932acbaf542265d85d2" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b13ac4806c064932acbaf542265d85d2 = echarts.init(
#                     document.getElementById('b13ac4806c064932acbaf542265d85d2'), 'light', {renderer: 'canvas'});
#                 var option_b13ac4806c064932acbaf542265d85d2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "pictorialBar",
#             "symbol": "path://M100,0 L41.22,180.90 L195.10,69.09 L4.89,69.09 L158.77,180.90 z",
#             "symbolSize": 20,
#             "symbolRepeat": "fixed",
#             "symbolClip": true,
#             "name": "A",
#             "data": [
#                 96,
#                 51,
#                 63,
#                 59,
#                 54,
#                 47,
#                 142
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A"
#             ],
#             "selected": {
#                 "A": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_b13ac4806c064932acbaf542265d85d2.setOption(option_b13ac4806c064932acbaf542265d85d2);
#         });
#     </script>

# %% [markdown]
# #### 31.

# %%
from pyecharts.charts import *
from pyecharts import options as opts

ios_icon = 'path://M24.734 17.003c-0.040-4.053 3.305-5.996 3.454-6.093-1.88-2.751-4.808-3.127-5.851-3.171-2.492-0.252-4.862 1.467-6.127 1.467-1.261 0-3.213-1.43-5.28-1.392-2.716 0.040-5.221 1.579-6.619 4.012-2.822 4.897-0.723 12.151 2.028 16.123 1.344 1.944 2.947 4.127 5.051 4.049 2.026-0.081 2.793-1.311 5.242-1.311s3.138 1.311 5.283 1.271c2.18-0.041 3.562-1.981 4.897-3.931 1.543-2.255 2.179-4.439 2.216-4.551-0.048-0.022-4.252-1.632-4.294-6.473zM20.705 5.11c1.117-1.355 1.871-3.235 1.665-5.11-1.609 0.066-3.559 1.072-4.713 2.423-1.036 1.199-1.942 3.113-1.699 4.951 1.796 0.14 3.629-0.913 4.747-2.264z'


def liquid_with_custom_shape():
    liquid = Liquid(init_opts=opts.InitOpts(theme='light',
                                            width='1000px',
                                            height='600px'))
    liquid.add('', [0.4, 0.5], shape=ios_icon)

    return liquid


chart = liquid_with_custom_shape()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/v5/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="523f8298364f44e384d2b38bfd295e0f" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_523f8298364f44e384d2b38bfd295e0f = echarts.init(
#                     document.getElementById('523f8298364f44e384d2b38bfd295e0f'), 'light', {renderer: 'canvas'});
#                 var option_523f8298364f44e384d2b38bfd295e0f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "liquidFill",
#             "data": [
#                 0.4,
#                 0.5
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "path://M24.734 17.003c-0.040-4.053 3.305-5.996 3.454-6.093-1.88-2.751-4.808-3.127-5.851-3.171-2.492-0.252-4.862 1.467-6.127 1.467-1.261 0-3.213-1.43-5.28-1.392-2.716 0.040-5.221 1.579-6.619 4.012-2.822 4.897-0.723 12.151 2.028 16.123 1.344 1.944 2.947 4.127 5.051 4.049 2.026-0.081 2.793-1.311 5.242-1.311s3.138 1.311 5.283 1.271c2.18-0.041 3.562-1.981 4.897-3.931 1.543-2.255 2.179-4.439 2.216-4.551-0.048-0.022-4.252-1.632-4.294-6.473zM20.705 5.11c1.117-1.355 1.871-3.235 1.665-5.11-1.609 0.066-3.559 1.072-4.713 2.423-1.036 1.199-1.942 3.113-1.699 4.951 1.796 0.14 3.629-0.913 4.747-2.264z",
#             "backgroundStyle": {},
#             "outline": {
#                 "show": true,
#                 "borderDistance": 8
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     }
# };
#                 chart_523f8298364f44e384d2b38bfd295e0f.setOption(option_523f8298364f44e384d2b38bfd295e0f);
#         });
#     </script>

# %% [markdown]
# #### 32.daycell

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import datetime

# coviddata
data = [(datetime.datetime(2020, 1, 21, 0, 0), 1), (datetime.datetime(2020, 1, 22, 0, 0), 1),
        (datetime.datetime(2020, 1, 23, 0, 0), 1), (datetime.datetime(2020, 1, 24, 0, 0), 2),
        (datetime.datetime(2020, 1, 25, 0, 0), 2), (datetime.datetime(2020, 1, 26, 0, 0), 5),
        (datetime.datetime(2020, 1, 27, 0, 0), 5), (datetime.datetime(2020, 1, 28, 0, 0), 5),
        (datetime.datetime(2020, 1, 29, 0, 0), 5), (datetime.datetime(2020, 1, 30, 0, 0), 5),
        (datetime.datetime(2020, 1, 31, 0, 0), 7), (datetime.datetime(2020, 2, 1, 0, 0), 8),
        (datetime.datetime(2020, 2, 2, 0, 0), 8), (datetime.datetime(2020, 2, 3, 0, 0), 11),
        (datetime.datetime(2020, 2, 4, 0, 0), 11), (datetime.datetime(2020, 2, 5, 0, 0), 11),
        (datetime.datetime(2020, 2, 6, 0, 0), 11), (datetime.datetime(2020, 2, 7, 0, 0), 11),
        (datetime.datetime(2020, 2, 8, 0, 0), 11), (datetime.datetime(2020, 2, 9, 0, 0), 11),
        (datetime.datetime(2020, 2, 10, 0, 0), 11), (datetime.datetime(2020, 2, 11, 0, 0), 12),
        (datetime.datetime(2020, 2, 12, 0, 0), 12), (datetime.datetime(2020, 2, 13, 0, 0), 13),
        (datetime.datetime(2020, 2, 14, 0, 0), 13), (datetime.datetime(2020, 2, 15, 0, 0), 13),
        (datetime.datetime(2020, 2, 16, 0, 0), 13), (datetime.datetime(2020, 2, 17, 0, 0), 13),
        (datetime.datetime(2020, 2, 18, 0, 0), 13), (datetime.datetime(2020, 2, 19, 0, 0), 13),
        (datetime.datetime(2020, 2, 20, 0, 0), 13), (datetime.datetime(2020, 2, 21, 0, 0), 15),
        (datetime.datetime(2020, 2, 22, 0, 0), 15), (datetime.datetime(2020, 2, 23, 0, 0), 15),
        (datetime.datetime(2020, 2, 24, 0, 0), 15), (datetime.datetime(2020, 2, 25, 0, 0), 15),
        (datetime.datetime(2020, 2, 26, 0, 0), 15), (datetime.datetime(2020, 2, 27, 0, 0), 16),
        (datetime.datetime(2020, 2, 28, 0, 0), 16), (datetime.datetime(2020, 2, 29, 0, 0), 24),
        (datetime.datetime(2020, 3, 1, 0, 0), 30), (datetime.datetime(2020, 3, 2, 0, 0), 53),
        (datetime.datetime(2020, 3, 3, 0, 0), 73), (datetime.datetime(2020, 3, 4, 0, 0), 104),
        (datetime.datetime(2020, 3, 5, 0, 0), 174), (datetime.datetime(2020, 3, 6, 0, 0), 222),
        (datetime.datetime(2020, 3, 7, 0, 0), 337), (datetime.datetime(2020, 3, 8, 0, 0), 451),
        (datetime.datetime(2020, 3, 9, 0, 0), 519), (datetime.datetime(2020, 3, 10, 0, 0), 711),
        (datetime.datetime(2020, 3, 11, 0, 0), 1109), (datetime.datetime(2020, 3, 12, 0, 0), 1561),
        (datetime.datetime(2020, 3, 13, 0, 0), 2157), (datetime.datetime(2020, 3, 14, 0, 0), 2870),
        (datetime.datetime(2020, 3, 15, 0, 0), 2968), (datetime.datetime(2020, 3, 16, 0, 0), 4360),
        (datetime.datetime(2020, 3, 17, 0, 0), 6141), (datetime.datetime(2020, 3, 18, 0, 0), 8914),
        (datetime.datetime(2020, 3, 19, 0, 0), 14153), (datetime.datetime(2020, 3, 20, 0, 0), 19479),
        (datetime.datetime(2020, 3, 21, 0, 0), 25818), (datetime.datetime(2020, 3, 22, 0, 0), 33756),
        (datetime.datetime(2020, 3, 23, 0, 0), 43845), (datetime.datetime(2020, 3, 24, 0, 0), 54108),
        (datetime.datetime(2020, 3, 25, 0, 0), 66044), (datetime.datetime(2020, 3, 26, 0, 0), 84080),
        (datetime.datetime(2020, 3, 27, 0, 0), 102254), (datetime.datetime(2020, 3, 28, 0, 0), 122054),
        (datetime.datetime(2020, 3, 29, 0, 0), 141194), (datetime.datetime(2020, 3, 30, 0, 0), 162690),
        (datetime.datetime(2020, 3, 31, 0, 0), 188701), (datetime.datetime(2020, 4, 1, 0, 0), 214194),
        (datetime.datetime(2020, 4, 2, 0, 0), 244593), (datetime.datetime(2020, 4, 3, 0, 0), 276535),
        (datetime.datetime(2020, 4, 4, 0, 0), 309699), (datetime.datetime(2020, 4, 5, 0, 0), 337573),
        (datetime.datetime(2020, 4, 6, 0, 0), 367210), (datetime.datetime(2020, 4, 7, 0, 0), 397992),
        (datetime.datetime(2020, 4, 8, 0, 0), 429686), (datetime.datetime(2020, 4, 9, 0, 0), 464442),
        (datetime.datetime(2020, 4, 10, 0, 0), 497943), (datetime.datetime(2020, 4, 11, 0, 0), 527958),
        (datetime.datetime(2020, 4, 12, 0, 0), 556517), (datetime.datetime(2020, 4, 13, 0, 0), 581810),
        (datetime.datetime(2020, 4, 14, 0, 0), 608845), (datetime.datetime(2020, 4, 15, 0, 0), 637974),
        (datetime.datetime(2020, 4, 16, 0, 0), 669272), (datetime.datetime(2020, 4, 17, 0, 0), 701996),
        (datetime.datetime(2020, 4, 18, 0, 0), 730317), (datetime.datetime(2020, 4, 19, 0, 0), 756375),
        (datetime.datetime(2020, 4, 20, 0, 0), 783716), (datetime.datetime(2020, 4, 21, 0, 0), 809213),
        (datetime.datetime(2020, 4, 22, 0, 0), 837414), (datetime.datetime(2020, 4, 23, 0, 0), 871617),
        (datetime.datetime(2020, 4, 24, 0, 0), 907908), (datetime.datetime(2020, 4, 25, 0, 0), 940829),
        (datetime.datetime(2020, 4, 26, 0, 0), 968517), (datetime.datetime(2020, 4, 27, 0, 0), 990993),
        (datetime.datetime(2020, 4, 28, 0, 0), 1015518), (datetime.datetime(2020, 4, 29, 0, 0), 1042926),
        (datetime.datetime(2020, 4, 30, 0, 0), 1072667)]


def calendar_custom_cell():
    calendar = Calendar(init_opts=opts.InitOpts(theme='light',
                                                width='1000px',
                                                height='600px'))
    calendar.add('',
                 yaxis_data=data,
                 label_opts=opts.LabelOpts(is_show=True),
                 calendar_opts=opts.CalendarOpts(
                     # day
                     pos_top='10%',
                     pos_left='10%',
                     # date
                     range_=['2020-01-21', '2020-04-30'],
                     # day
                     cell_size=50,
                     # yearmonthdaylabel
                     yearlabel_opts=opts.CalendarYearLabelOpts(margin=40,
                                                               label_font_size=20,
                                                               label_color='rgba(130,134,112,0.8)'),
                     daylabel_opts=opts.CalendarDayLabelOpts(label_color='#778633', label_font_weight='bold'),
                     monthlabel_opts=opts.CalendarMonthLabelOpts(label_color='#778633', label_font_weight='bold')
                 )
                 )
    # 
    calendar.set_global_opts(visualmap_opts=opts.VisualMapOpts(
        max_=1000000,
        is_piecewise=True,
        pieces=[{"min": 1000000},
                {"min": 10000, "max": 1000000},
                {"min": 100, "max": 10000},
                {"max": 100}],
        range_color=["#CCD3D9", "#E6B6C2", "#D4587A", "#DC364C"]
    ))
    return calendar


chart = calendar_custom_cell()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1f1a058fba65447eaf10b9419d59ee6a" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1f1a058fba65447eaf10b9419d59ee6a = echarts.init(
#                     document.getElementById('1f1a058fba65447eaf10b9419d59ee6a'), 'light', {renderer: 'canvas'});
#                 var option_1f1a058fba65447eaf10b9419d59ee6a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "name": "\u786e\u8bc1\u4eba\u6570",
#             "data": [
#                 [
#                     "2020-01-21T00:00:00",
#                     1
#                 ],
#                 [
#                     "2020-01-22T00:00:00",
#                     1
#                 ],
#                 [
#                     "2020-01-23T00:00:00",
#                     1
#                 ],
#                 [
#                     "2020-01-24T00:00:00",
#                     2
#                 ],
#                 [
#                     "2020-01-25T00:00:00",
#                     2
#                 ],
#                 [
#                     "2020-01-26T00:00:00",
#                     5
#                 ],
#                 [
#                     "2020-01-27T00:00:00",
#                     5
#                 ],
#                 [
#                     "2020-01-28T00:00:00",
#                     5
#                 ],
#                 [
#                     "2020-01-29T00:00:00",
#                     5
#                 ],
#                 [
#                     "2020-01-30T00:00:00",
#                     5
#                 ],
#                 [
#                     "2020-01-31T00:00:00",
#                     7
#                 ],
#                 [
#                     "2020-02-01T00:00:00",
#                     8
#                 ],
#                 [
#                     "2020-02-02T00:00:00",
#                     8
#                 ],
#                 [
#                     "2020-02-03T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-04T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-05T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-06T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-07T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-08T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-09T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-10T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-11T00:00:00",
#                     12
#                 ],
#                 [
#                     "2020-02-12T00:00:00",
#                     12
#                 ],
#                 [
#                     "2020-02-13T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-14T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-15T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-16T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-17T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-18T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-19T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-20T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-21T00:00:00",
#                     15
#                 ],
#                 [
#                     "2020-02-22T00:00:00",
#                     15
#                 ],
#                 [
#                     "2020-02-23T00:00:00",
#                     15
#                 ],
#                 [
#                     "2020-02-24T00:00:00",
#                     15
#                 ],
#                 [
#                     "2020-02-25T00:00:00",
#                     15
#                 ],
#                 [
#                     "2020-02-26T00:00:00",
#                     15
#                 ],
#                 [
#                     "2020-02-27T00:00:00",
#                     16
#                 ],
#                 [
#                     "2020-02-28T00:00:00",
#                     16
#                 ],
#                 [
#                     "2020-02-29T00:00:00",
#                     24
#                 ],
#                 [
#                     "2020-03-01T00:00:00",
#                     30
#                 ],
#                 [
#                     "2020-03-02T00:00:00",
#                     53
#                 ],
#                 [
#                     "2020-03-03T00:00:00",
#                     73
#                 ],
#                 [
#                     "2020-03-04T00:00:00",
#                     104
#                 ],
#                 [
#                     "2020-03-05T00:00:00",
#                     174
#                 ],
#                 [
#                     "2020-03-06T00:00:00",
#                     222
#                 ],
#                 [
#                     "2020-03-07T00:00:00",
#                     337
#                 ],
#                 [
#                     "2020-03-08T00:00:00",
#                     451
#                 ],
#                 [
#                     "2020-03-09T00:00:00",
#                     519
#                 ],
#                 [
#                     "2020-03-10T00:00:00",
#                     711
#                 ],
#                 [
#                     "2020-03-11T00:00:00",
#                     1109
#                 ],
#                 [
#                     "2020-03-12T00:00:00",
#                     1561
#                 ],
#                 [
#                     "2020-03-13T00:00:00",
#                     2157
#                 ],
#                 [
#                     "2020-03-14T00:00:00",
#                     2870
#                 ],
#                 [
#                     "2020-03-15T00:00:00",
#                     2968
#                 ],
#                 [
#                     "2020-03-16T00:00:00",
#                     4360
#                 ],
#                 [
#                     "2020-03-17T00:00:00",
#                     6141
#                 ],
#                 [
#                     "2020-03-18T00:00:00",
#                     8914
#                 ],
#                 [
#                     "2020-03-19T00:00:00",
#                     14153
#                 ],
#                 [
#                     "2020-03-20T00:00:00",
#                     19479
#                 ],
#                 [
#                     "2020-03-21T00:00:00",
#                     25818
#                 ],
#                 [
#                     "2020-03-22T00:00:00",
#                     33756
#                 ],
#                 [
#                     "2020-03-23T00:00:00",
#                     43845
#                 ],
#                 [
#                     "2020-03-24T00:00:00",
#                     54108
#                 ],
#                 [
#                     "2020-03-25T00:00:00",
#                     66044
#                 ],
#                 [
#                     "2020-03-26T00:00:00",
#                     84080
#                 ],
#                 [
#                     "2020-03-27T00:00:00",
#                     102254
#                 ],
#                 [

# %% [markdown]
# #### 33.daylabel

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import datetime

# coviddata
data = [(datetime.datetime(2020, 1, 21, 0, 0), 1), (datetime.datetime(2020, 1, 22, 0, 0), 1),
        (datetime.datetime(2020, 1, 23, 0, 0), 1), (datetime.datetime(2020, 1, 24, 0, 0), 2),
        (datetime.datetime(2020, 1, 25, 0, 0), 2), (datetime.datetime(2020, 1, 26, 0, 0), 5),
        (datetime.datetime(2020, 1, 27, 0, 0), 5), (datetime.datetime(2020, 1, 28, 0, 0), 5),
        (datetime.datetime(2020, 1, 29, 0, 0), 5), (datetime.datetime(2020, 1, 30, 0, 0), 5),
        (datetime.datetime(2020, 1, 31, 0, 0), 7), (datetime.datetime(2020, 2, 1, 0, 0), 8),
        (datetime.datetime(2020, 2, 2, 0, 0), 8), (datetime.datetime(2020, 2, 3, 0, 0), 11),
        (datetime.datetime(2020, 2, 4, 0, 0), 11), (datetime.datetime(2020, 2, 5, 0, 0), 11),
        (datetime.datetime(2020, 2, 6, 0, 0), 11), (datetime.datetime(2020, 2, 7, 0, 0), 11),
        (datetime.datetime(2020, 2, 8, 0, 0), 11), (datetime.datetime(2020, 2, 9, 0, 0), 11),
        (datetime.datetime(2020, 2, 10, 0, 0), 11), (datetime.datetime(2020, 2, 11, 0, 0), 12),
        (datetime.datetime(2020, 2, 12, 0, 0), 12), (datetime.datetime(2020, 2, 13, 0, 0), 13),
        (datetime.datetime(2020, 2, 14, 0, 0), 13), (datetime.datetime(2020, 2, 15, 0, 0), 13),
        (datetime.datetime(2020, 2, 16, 0, 0), 13), (datetime.datetime(2020, 2, 17, 0, 0), 13),
        (datetime.datetime(2020, 2, 18, 0, 0), 13), (datetime.datetime(2020, 2, 19, 0, 0), 13),
        (datetime.datetime(2020, 2, 20, 0, 0), 13), (datetime.datetime(2020, 2, 21, 0, 0), 15),
        (datetime.datetime(2020, 2, 22, 0, 0), 15), (datetime.datetime(2020, 2, 23, 0, 0), 15),
        (datetime.datetime(2020, 2, 24, 0, 0), 15), (datetime.datetime(2020, 2, 25, 0, 0), 15),
        (datetime.datetime(2020, 2, 26, 0, 0), 15), (datetime.datetime(2020, 2, 27, 0, 0), 16),
        (datetime.datetime(2020, 2, 28, 0, 0), 16), (datetime.datetime(2020, 2, 29, 0, 0), 24),
        (datetime.datetime(2020, 3, 1, 0, 0), 30), (datetime.datetime(2020, 3, 2, 0, 0), 53),
        (datetime.datetime(2020, 3, 3, 0, 0), 73), (datetime.datetime(2020, 3, 4, 0, 0), 104),
        (datetime.datetime(2020, 3, 5, 0, 0), 174), (datetime.datetime(2020, 3, 6, 0, 0), 222),
        (datetime.datetime(2020, 3, 7, 0, 0), 337), (datetime.datetime(2020, 3, 8, 0, 0), 451),
        (datetime.datetime(2020, 3, 9, 0, 0), 519), (datetime.datetime(2020, 3, 10, 0, 0), 711),
        (datetime.datetime(2020, 3, 11, 0, 0), 1109), (datetime.datetime(2020, 3, 12, 0, 0), 1561),
        (datetime.datetime(2020, 3, 13, 0, 0), 2157), (datetime.datetime(2020, 3, 14, 0, 0), 2870),
        (datetime.datetime(2020, 3, 15, 0, 0), 2968), (datetime.datetime(2020, 3, 16, 0, 0), 4360),
        (datetime.datetime(2020, 3, 17, 0, 0), 6141), (datetime.datetime(2020, 3, 18, 0, 0), 8914),
        (datetime.datetime(2020, 3, 19, 0, 0), 14153), (datetime.datetime(2020, 3, 20, 0, 0), 19479),
        (datetime.datetime(2020, 3, 21, 0, 0), 25818), (datetime.datetime(2020, 3, 22, 0, 0), 33756),
        (datetime.datetime(2020, 3, 23, 0, 0), 43845), (datetime.datetime(2020, 3, 24, 0, 0), 54108),
        (datetime.datetime(2020, 3, 25, 0, 0), 66044), (datetime.datetime(2020, 3, 26, 0, 0), 84080),
        (datetime.datetime(2020, 3, 27, 0, 0), 102254), (datetime.datetime(2020, 3, 28, 0, 0), 122054),
        (datetime.datetime(2020, 3, 29, 0, 0), 141194), (datetime.datetime(2020, 3, 30, 0, 0), 162690),
        (datetime.datetime(2020, 3, 31, 0, 0), 188701), (datetime.datetime(2020, 4, 1, 0, 0), 214194),
        (datetime.datetime(2020, 4, 2, 0, 0), 244593), (datetime.datetime(2020, 4, 3, 0, 0), 276535),
        (datetime.datetime(2020, 4, 4, 0, 0), 309699), (datetime.datetime(2020, 4, 5, 0, 0), 337573),
        (datetime.datetime(2020, 4, 6, 0, 0), 367210), (datetime.datetime(2020, 4, 7, 0, 0), 397992),
        (datetime.datetime(2020, 4, 8, 0, 0), 429686), (datetime.datetime(2020, 4, 9, 0, 0), 464442),
        (datetime.datetime(2020, 4, 10, 0, 0), 497943), (datetime.datetime(2020, 4, 11, 0, 0), 527958),
        (datetime.datetime(2020, 4, 12, 0, 0), 556517), (datetime.datetime(2020, 4, 13, 0, 0), 581810),
        (datetime.datetime(2020, 4, 14, 0, 0), 608845), (datetime.datetime(2020, 4, 15, 0, 0), 637974),
        (datetime.datetime(2020, 4, 16, 0, 0), 669272), (datetime.datetime(2020, 4, 17, 0, 0), 701996),
        (datetime.datetime(2020, 4, 18, 0, 0), 730317), (datetime.datetime(2020, 4, 19, 0, 0), 756375),
        (datetime.datetime(2020, 4, 20, 0, 0), 783716), (datetime.datetime(2020, 4, 21, 0, 0), 809213),
        (datetime.datetime(2020, 4, 22, 0, 0), 837414), (datetime.datetime(2020, 4, 23, 0, 0), 871617),
        (datetime.datetime(2020, 4, 24, 0, 0), 907908), (datetime.datetime(2020, 4, 25, 0, 0), 940829),
        (datetime.datetime(2020, 4, 26, 0, 0), 968517), (datetime.datetime(2020, 4, 27, 0, 0), 990993),
        (datetime.datetime(2020, 4, 28, 0, 0), 1015518), (datetime.datetime(2020, 4, 29, 0, 0), 1042926),
        (datetime.datetime(2020, 4, 30, 0, 0), 1072667)]


def calendar_in_Chinese():
    calendar = Calendar(init_opts=opts.InitOpts(theme='light',
                                                width='1000px',
                                                height='600px'))
    calendar.add('',
                 yaxis_data=data,
                 label_opts=opts.LabelOpts(is_show=True),
                 calendar_opts=opts.CalendarOpts(
                     # date
                     range_=['2020-01-21', '2020-04-30'],
                     # day
                     cell_size=50,
                     # yearmonthdaylabel
                     #  and Month，
                     yearlabel_opts=opts.CalendarYearLabelOpts(margin=50),
                     daylabel_opts=opts.CalendarDayLabelOpts(name_map='cn'),
                     monthlabel_opts=opts.CalendarMonthLabelOpts(name_map='cn')
                 )
                 )
    # 
    calendar.set_global_opts(visualmap_opts=opts.VisualMapOpts(
        max_=1000000,
        is_piecewise=True,
        pieces=[{"min": 1000000},
                {"min": 10000, "max": 1000000},
                {"min": 100, "max": 10000},
                {"max": 100}],
        range_color=["#CCD3D9", "#E6B6C2", "#D4587A", "#DC364C"]
    ))
    return calendar


chart = calendar_in_Chinese()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dcce25668ae249deb3292afefce76d6e" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dcce25668ae249deb3292afefce76d6e = echarts.init(
#                     document.getElementById('dcce25668ae249deb3292afefce76d6e'), 'light', {renderer: 'canvas'});
#                 var option_dcce25668ae249deb3292afefce76d6e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "name": "\u786e\u8bca\u4eba\u6570",
#             "data": [
#                 [
#                     "2020-01-21T00:00:00",
#                     1
#                 ],
#                 [
#                     "2020-01-22T00:00:00",
#                     1
#                 ],
#                 [
#                     "2020-01-23T00:00:00",
#                     1
#                 ],
#                 [
#                     "2020-01-24T00:00:00",
#                     2
#                 ],
#                 [
#                     "2020-01-25T00:00:00",
#                     2
#                 ],
#                 [
#                     "2020-01-26T00:00:00",
#                     5
#                 ],
#                 [
#                     "2020-01-27T00:00:00",
#                     5
#                 ],
#                 [
#                     "2020-01-28T00:00:00",
#                     5
#                 ],
#                 [
#                     "2020-01-29T00:00:00",
#                     5
#                 ],
#                 [
#                     "2020-01-30T00:00:00",
#                     5
#                 ],
#                 [
#                     "2020-01-31T00:00:00",
#                     7
#                 ],
#                 [
#                     "2020-02-01T00:00:00",
#                     8
#                 ],
#                 [
#                     "2020-02-02T00:00:00",
#                     8
#                 ],
#                 [
#                     "2020-02-03T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-04T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-05T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-06T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-07T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-08T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-09T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-10T00:00:00",
#                     11
#                 ],
#                 [
#                     "2020-02-11T00:00:00",
#                     12
#                 ],
#                 [
#                     "2020-02-12T00:00:00",
#                     12
#                 ],
#                 [
#                     "2020-02-13T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-14T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-15T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-16T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-17T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-18T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-19T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-20T00:00:00",
#                     13
#                 ],
#                 [
#                     "2020-02-21T00:00:00",
#                     15
#                 ],
#                 [
#                     "2020-02-22T00:00:00",
#                     15
#                 ],
#                 [
#                     "2020-02-23T00:00:00",
#                     15
#                 ],
#                 [
#                     "2020-02-24T00:00:00",
#                     15
#                 ],
#                 [
#                     "2020-02-25T00:00:00",
#                     15
#                 ],
#                 [
#                     "2020-02-26T00:00:00",
#                     15
#                 ],
#                 [
#                     "2020-02-27T00:00:00",
#                     16
#                 ],
#                 [
#                     "2020-02-28T00:00:00",
#                     16
#                 ],
#                 [
#                     "2020-02-29T00:00:00",
#                     24
#                 ],
#                 [
#                     "2020-03-01T00:00:00",
#                     30
#                 ],
#                 [
#                     "2020-03-02T00:00:00",
#                     53
#                 ],
#                 [
#                     "2020-03-03T00:00:00",
#                     73
#                 ],
#                 [
#                     "2020-03-04T00:00:00",
#                     104
#                 ],
#                 [
#                     "2020-03-05T00:00:00",
#                     174
#                 ],
#                 [
#                     "2020-03-06T00:00:00",
#                     222
#                 ],
#                 [
#                     "2020-03-07T00:00:00",
#                     337
#                 ],
#                 [
#                     "2020-03-08T00:00:00",
#                     451
#                 ],
#                 [
#                     "2020-03-09T00:00:00",
#                     519
#                 ],
#                 [
#                     "2020-03-10T00:00:00",
#                     711
#                 ],
#                 [
#                     "2020-03-11T00:00:00",
#                     1109
#                 ],
#                 [
#                     "2020-03-12T00:00:00",
#                     1561
#                 ],
#                 [
#                     "2020-03-13T00:00:00",
#                     2157
#                 ],
#                 [
#                     "2020-03-14T00:00:00",
#                     2870
#                 ],
#                 [
#                     "2020-03-15T00:00:00",
#                     2968
#                 ],
#                 [
#                     "2020-03-16T00:00:00",
#                     4360
#                 ],
#                 [
#                     "2020-03-17T00:00:00",
#                     6141
#                 ],
#                 [
#                     "2020-03-18T00:00:00",
#                     8914
#                 ],
#                 [
#                     "2020-03-19T00:00:00",
#                     14153
#                 ],
#                 [
#                     "2020-03-20T00:00:00",
#                     19479
#                 ],
#                 [
#                     "2020-03-21T00:00:00",
#                     25818
#                 ],
#                 [
#                     "2020-03-22T00:00:00",
#                     33756
#                 ],
#                 [
#                     "2020-03-23T00:00:00",
#                     43845
#                 ],
#                 [
#                     "2020-03-24T00:00:00",
#                     54108
#                 ],
#                 [
#                     "2020-03-25T00:00:00",
#                     66044
#                 ],
#                 [
#                     "2020-03-26T00:00:00",
#                     84080
#                 ],
#                 [
#                     "2020-03-27T00:00:00",
#                     102254
#                 ],
#                 [

# %% [markdown]
# #### 34.GEO

# %%
from pyecharts.charts import *
from pyecharts import options as opts


def geo_add_custom_coordinate():
    geo = Geo(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    # 
    geo.add_coordinate('x', 116.397428, 39.90923)
    geo.add_coordinate('y', 112.398615, 29.91659)

    geo.add_schema(maptype="china")
    geo.add("", [('x', 1), ('y', 2)])

    return geo


chart = geo_add_custom_coordinate()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="d453d47f8ffe49fabfc5c4d8efacaf74" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_d453d47f8ffe49fabfc5c4d8efacaf74 = echarts.init(
#                     document.getElementById('d453d47f8ffe49fabfc5c4d8efacaf74'), 'light', {renderer: 'canvas'});
#                 var option_d453d47f8ffe49fabfc5c4d8efacaf74 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "x",
#                     "value": [
#                         116.397428,
#                         39.90923,
#                         1
#                     ]
#                 },
#                 {
#                     "name": "y",
#                     "value": [
#                         112.398615,
#                         29.91659,
#                         2
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_d453d47f8ffe49fabfc5c4d8efacaf74.setOption(option_d453d47f8ffe49fabfc5c4d8efacaf74);
#         });
#     </script>

# %% [markdown]
# #### 35.GEOusing

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.datasets import register_url
import ssl


def geo_foreign_country():
    # 
    # noinspection PyBroadException
    try:
        register_url("https://echarts-maps.github.io/echarts-countries-js/")
    except Exception:
        ssl._create_default_https_context = ssl._create_unverified_context
        register_url("https://echarts-maps.github.io/echarts-countries-js/")

    geo = Geo(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))

    geo.add_schema(maptype="")

    return geo


chart = geo_foreign_country()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', '':'https://assets.pyecharts.org/assets/v5/maps/USA'
#         }
#     });
# </script>
#
#         <div id="ef78d49eaf9e4fc78acd8081d4848c38" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts', ''], function(echarts) {
#                 var chart_ef78d49eaf9e4fc78acd8081d4848c38 = echarts.init(
#                     document.getElementById('ef78d49eaf9e4fc78acd8081d4848c38'), 'light', {renderer: 'canvas'});
#                 var option_ef78d49eaf9e4fc78acd8081d4848c38 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "geo": {
#         "map": "\u7f8e\u56fd",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_ef78d49eaf9e4fc78acd8081d4848c38.setOption(option_ef78d49eaf9e4fc78acd8081d4848c38);
#         });
#     </script>

# %% [markdown]
# #### 36.GEO Effectiveness

# %%
from pyecharts.charts import *
from pyecharts import options as opts


def geo_effect_scatter():
    geo = Geo(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))

    geo.add_schema(maptype="china")

    geo.add("",
            [("", 150), ("", 70), ("", 64), ("", 74),  ("", 63)],
            # Effectiveness
            type_='effectScatter')

    return geo


chart = geo_effect_scatter()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="f4004466c93544818470e141a51270cf" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_f4004466c93544818470e141a51270cf = echarts.init(
#                     document.getElementById('f4004466c93544818470e141a51270cf'), 'light', {renderer: 'canvas'});
#                 var option_f4004466c93544818470e141a51270cf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         150
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         70
#                     ]
#                 },
#                 {
#                     "name": "\u957f\u6c99",
#                     "value": [
#                         113,
#                         28.21,
#                         64
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         74
#                     ]
#                 },
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": [
#                         118.1,
#                         24.46,
#                         63
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_f4004466c93544818470e141a51270cf.setOption(option_f4004466c93544818470e141a51270cf);
#         });
#     </script>

# %% [markdown]
# #### 37.GEO

# %%
from pyecharts.charts import *
from pyecharts import options as opts


def geo_heatmap():
    geo = Geo(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))

    geo.add_schema(maptype="china")

    geo.add("",
            [("", 150), ("", 70), ("", 64), ("", 74),  ("", 63)],
            type_='heatmap')
    # visualmap_opts
    geo.set_global_opts(visualmap_opts=opts.VisualMapOpts())
    return geo


chart = geo_heatmap()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="789dc3aaeada4e3da2d7aac501db0a82" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_789dc3aaeada4e3da2d7aac501db0a82 = echarts.init(
#                     document.getElementById('789dc3aaeada4e3da2d7aac501db0a82'), 'light', {renderer: 'canvas'});
#                 var option_789dc3aaeada4e3da2d7aac501db0a82 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         150
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         70
#                     ]
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": [
#                         114.07,
#                         22.62,
#                         64
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         74
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         63
#                     ]
#                 }
#             ],
#             "pointSize": 20,
#             "blurSize": 20
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_789dc3aaeada4e3da2d7aac501db0a82.setOption(option_789dc3aaeada4e3da2d7aac501db0a82);
#         });
#     </script>

# %% [markdown]
# #### 38.GEO

# %%
from pyecharts.charts import *
from pyecharts import options as opts


def geo_lines():
    geo = Geo(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))

    geo.add_schema(maptype="china")

    geo.add("",
            # data（from， to）
            [("", ""), ("", ""), ("", ""), ("", "")],
            type_='lines')
    geo.add("",
            # data（from， to）
            [("", ''), ("", ""), ("", ""), ("", "")],
            type_='lines')

    return geo


chart = geo_lines()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="b65618946f19434096177ade327dde5f" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_b65618946f19434096177ade327dde5f = echarts.init(
#                     document.getElementById('b65618946f19434096177ade327dde5f'), 'light', {renderer: 'canvas'});
#                 var option_b65618946f19434096177ade327dde5f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "lines",
#             "name": "\u5e7f\u5dde\u51fa\u53d1",
#             "coordinateSystem": "geo",
#             "zlevel": 2,
#             "progressive": 400,
#             "progressiveThreshold": 3000,
#             "effect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "polyline": false,
#             "large": false,
#             "largeThreshold": 2000,
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde->\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.473701,
#                             31.230416
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u897f\u5b81",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             101.74,
#                             36.56
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.551556,
#                             29.563009
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "lines",
#             "name": "\u6210\u90fd\u51fa\u53d1",
#             "coordinateSystem": "geo",
#             "zlevel": 3,
#             "progressive": 400,
#             "progressiveThreshold": 3000,
#             "effect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "polyline": false,
#             "large": false,
#             "largeThreshold": 2000,
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u6210\u90fd->\u957f\u6c99",
#                     "coords": [
#                         [
#                             104.06,
#                             30.67
#                         ],
#                         [
#                             113,
#                             28.21
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd->\u6b66\u6c49",
#                     "coords": [
#                         [
#                             104.06,
#                             30.67
#                         ],
#                         [
#                             114.31,
#                             30.52
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd->\u957f\u6625",
#                     "coords": [
#                         [
#                             104.06,
#                             30.67
#                         ],
#                         [
#                             125.35,
#                             43.88
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd->\u5357\u4eac",
#                     "coords": [
#                         [
#                             104.06,
#                             30.67
#                         ],
#                         [
#                             118.78,
#                             32.04
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e7f\u5dde\u51fa\u53d1",
#                 "\u6210\u90fd\u51fa\u53d1"
#             ],
#             "selected": {
#                 "\u5e7f\u5dde\u51fa\u53d1": true,
#                 "\u6210\u90fd\u51fa\u53d1": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode"

# %% [markdown]
# #### 39.

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def pie_custom_radius():
    pie = Pie(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    pie.add("",
            [list(z) for z in zip(Faker.choose(), Faker.values())],
            # ，0%-100%
            radius=["40%", "75%"])

    return pie


chart = pie_custom_radius()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f6f4d6b43027416f8c5f41f6d6157bce" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f6f4d6b43027416f8c5f41f6d6157bce = echarts.init(
#                     document.getElementById('f6f4d6b43027416f8c5f41f6d6157bce'), 'light', {renderer: 'canvas'});
#                 var option_f6f4d6b43027416f8c5f41f6d6157bce = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u6cb3\u9a6c",
#                     "value": 144
#                 },
#                 {
#                     "name": "\u87d2\u86c7",
#                     "value": 140
#                 },
#                 {
#                     "name": "\u8001\u864e",
#                     "value": 89
#                 },
#                 {
#                     "name": "\u5927\u8c61",
#                     "value": 104
#                 },
#                 {
#                     "name": "\u5154\u5b50",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u718a\u732b",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u72ee\u5b50",
#                     "value": 75
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     }
# };
#                 chart_f6f4d6b43027416f8c5f41f6d6157bce.setOption(option_f6f4d6b43027416f8c5f41f6d6157bce);
#         });
#     </script>

# %% [markdown]
# #### 40.datalabel

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def pie_with_custom_label():
    pie = Pie(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='600px'))
    pie.add("", [list(z) for z in zip(Faker.choose(), Faker.values())])
    pie.set_series_opts(
        # datalabel
        label_opts=opts.LabelOpts(position='top',
                                  color='red',
                                  font_family='Arial',
                                  font_size=12,
                                  font_style='italic',
                                  interval=1,
                                  formatter='{b}:{d}%'
                                  )
    )

    return pie


chart = pie_with_custom_label()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c182407f83ee47028e4a3534d451ee40" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c182407f83ee47028e4a3534d451ee40 = echarts.init(
#                     document.getElementById('c182407f83ee47028e4a3534d451ee40'), 'light', {renderer: 'canvas'});
#                 var option_c182407f83ee47028e4a3534d451ee40 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u5c0f\u7c73",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u4e09\u661f",
#                     "value": 115
#                 },
#                 {
#                     "name": "\u534e\u4e3a",
#                     "value": 48
#                 },
#                 {
#                     "name": "\u82f9\u679c",
#                     "value": 83
#                 },
#                 {
#                     "name": "\u9b45\u65cf",
#                     "value": 88
#                 },
#                 {
#                     "name": "VIVO",
#                     "value": 33
#                 },
#                 {
#                     "name": "OPPO",
#                     "value": 120
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": "red",
#                 "margin": 8,
#                 "interval": 1,
#                 "fontSize": 12,
#                 "fontStyle": "italic",
#                 "fontFamily": "Arial",
#                 "formatter": "{b}:{d}%"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     }
# };
#                 chart_c182407f83ee47028e4a3534d451ee40.setOption(option_c182407f83ee47028e4a3534d451ee40);
#         });
#     </script>

# %% [markdown]
# #### 41.

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def pie_multiple():
    pie = Pie(init_opts=opts.InitOpts(theme='light',
                                      width='1000px',
                                      height='800px'))
    pie.add("",
            [list(z) for z in zip(Faker.choose(), Faker.values())],
            radius=["20%", "50%"],
            center=["25%", "50%"])
    # 
    pie.add("",
            [list(z) for z in zip(Faker.choose(), Faker.values())],
            radius=["20%", "50%"],
            center=["75%", "50%"])

    return pie


chart = pie_multiple()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a8a202d215924e9ebc3546aff03cc1eb" style="width:1000px; height:800px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a8a202d215924e9ebc3546aff03cc1eb = echarts.init(
#                     document.getElementById('a8a202d215924e9ebc3546aff03cc1eb'), 'light', {renderer: 'canvas'});
#                 var option_a8a202d215924e9ebc3546aff03cc1eb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u5c0f\u7c73",
#                     "value": 62
#                 },
#                 {
#                     "name": "\u4e09\u661f",
#                     "value": 147
#                 },
#                 {
#                     "name": "\u534e\u4e3a",
#                     "value": 98
#                 },
#                 {
#                     "name": "\u82f9\u679c",
#                     "value": 98
#                 },
#                 {
#                     "name": "\u9b45\u65cf",
#                     "value": 58
#                 },
#                 {
#                     "name": "VIVO",
#                     "value": 102
#                 },
#                 {
#                     "name": "OPPO",
#                     "value": 92
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "50%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         },
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u5468\u4e00",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u5468\u4e8c",
#                     "value": 139
#                 },
#                 {
#                     "name": "\u5468\u4e09",
#                     "value": 105
#                 },
#                 {
#                     "name": "\u5468\u56db",
#                     "value": 49
#                 },
#                 {
#                     "name": "\u5468\u4e94",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u5468\u516d",
#                     "value": 148
#                 },
#                 {
#                     "name": "\u5468\u65e5",
#                     "value": 86
#                 }
#             ],
#             "radius": [
#                 "20%",
#                 "50%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO",
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ],
#             "selected": {}
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     }
# };
#                 chart_a8a202d215924e9ebc3546aff03cc1eb.setOption(option_a8a202d215924e9ebc3546aff03cc1eb);
#         });
#     </script>

# %% [markdown]
# #### 42.（）

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def scatter_with_visualmap_size():
    scatter = Scatter(init_opts=opts.InitOpts(theme='light',
                                              width='1000px',
                                              height='600px'))
    scatter.add_xaxis(Faker.choose())
    scatter.add_yaxis('', Faker.values())
    # 
    scatter.set_global_opts(visualmap_opts=opts.VisualMapOpts(type_='size'))
    return scatter


chart = scatter_with_visualmap_size()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="89ff2155121a43f68a72d3427ed3814f" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_89ff2155121a43f68a72d3427ed3814f = echarts.init(
#                     document.getElementById('89ff2155121a43f68a72d3427ed3814f'), 'light', {renderer: 'canvas'});
#                 var option_89ff2155121a43f68a72d3427ed3814f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     67
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     123
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     31
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     139
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     20
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     83
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     69
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "symbolSize": [
#                 20,
#                 50
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_89ff2155121a43f68a72d3427ed3814f.setOption(option_89ff2155121a43f68a72d3427ed3814f);
#         });
#     </script>

# %% [markdown]
# #### 43.（&Color）

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data = [random.randint(0, 100) for _ in range(30)]
y_data = [(random.randint(0, 100), random.randint(0, 100), random.randint(0, 100)) for _ in range(30)]


def scatter_with_visualmap_color_size():
    scatter = Scatter(init_opts=opts.InitOpts(theme='light',
                                              width='1000px',
                                              height='600px'))
    scatter.add_xaxis(x_data)
    scatter.add_yaxis('', y_data)
    # through list
    # dimensiondata
    scatter.set_global_opts(visualmap_opts=[opts.VisualMapOpts(is_show=True, type_='size', dimension=2, pos_top='20%'),
                                            opts.VisualMapOpts(is_show=True, type_='color', dimension=3,  pos_top='60%')
                                            ],
                            xaxis_opts=opts.AxisOpts(type_="value"))
    return scatter


chart = scatter_with_visualmap_color_size()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a8f29ccfc361446c987767cb56fed704" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a8f29ccfc361446c987767cb56fed704 = echarts.init(
#                     document.getElementById('a8f29ccfc361446c987767cb56fed704'), 'light', {renderer: 'canvas'});
#                 var option_a8f29ccfc361446c987767cb56fed704 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     74,
#                     22,
#                     32,
#                     29
#                 ],
#                 [
#                     31,
#                     60,
#                     13,
#                     94
#                 ],
#                 [
#                     6,
#                     95,
#                     6,
#                     34
#                 ],
#                 [
#                     86,
#                     3,
#                     35,
#                     100
#                 ],
#                 [
#                     42,
#                     53,
#                     27,
#                     29
#                 ],
#                 [
#                     19,
#                     55,
#                     19,
#                     89
#                 ],
#                 [
#                     88,
#                     97,
#                     10,
#                     86
#                 ],
#                 [
#                     91,
#                     10,
#                     54,
#                     56
#                 ],
#                 [
#                     85,
#                     38,
#                     13,
#                     68
#                 ],
#                 [
#                     18,
#                     25,
#                     19,
#                     5
#                 ],
#                 [
#                     48,
#                     68,
#                     7,
#                     27
#                 ],
#                 [
#                     87,
#                     58,
#                     22,
#                     92
#                 ],
#                 [
#                     51,
#                     18,
#                     44,
#                     77
#                 ],
#                 [
#                     54,
#                     30,
#                     23,
#                     98
#                 ],
#                 [
#                     19,
#                     94,
#                     86,
#                     69
#                 ],
#                 [
#                     42,
#                     87,
#                     38,
#                     0
#                 ],
#                 [
#                     22,
#                     5,
#                     60,
#                     24
#                 ],
#                 [
#                     30,
#                     50,
#                     89,
#                     51
#                 ],
#                 [
#                     90,
#                     14,
#                     52,
#                     69
#                 ],
#                 [
#                     42,
#                     41,
#                     76,
#                     0
#                 ],
#                 [
#                     31,
#                     74,
#                     71,
#                     12
#                 ],
#                 [
#                     74,
#                     5,
#                     7,
#                     43
#                 ],
#                 [
#                     12,
#                     97,
#                     91,
#                     60
#                 ],
#                 [
#                     88,
#                     42,
#                     46,
#                     7
#                 ],
#                 [
#                     40,
#                     29,
#                     64,
#                     21
#                 ],
#                 [
#                     75,
#                     69,
#                     11,
#                     61
#                 ],
#                 [
#                     44,
#                     77,
#                     45,
#                     10
#                 ],
#                 [
#                     30,
#                     16,
#                     1,
#                     24
#                 ],
#                 [
#                     73,
#                     15,
#                     67,
#                     22
#                 ],
#                 [
#                     33,
#                     32,
#                     69,
#                     44
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 74,
#                 31,
#                 6,
#                 86,
#                 42,
#                 19,
#                 88,
#                 91,
#                 85,
#                 18,
#                 48,
#                 87,
#                 51,
#                 54,
#                 19,
#                 42,
#                 22,
#                 30,
#                 90,
#                 42,
#                 31,
#                 74,
#                 12,
#                 88,
#                 40,
#                 75,
#                 44,
#                 30,
#                 73,
#                 33
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "split

# %% [markdown]
# #### 44.（&Color&）

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data = [random.randint(0, 100) for _ in range(30)]
y_data = [(random.randint(0, 100), random.randint(0, 100), random.randint(0, 100), random.randint(0, 100))
          for _ in range(30)]


def scatter_with_visualmap_color_size_opacity():
    scatter = Scatter(init_opts=opts.InitOpts(theme='light',
                                              width='1000px',
                                              height='600px'))
    scatter.add_xaxis(x_data)
    scatter.add_yaxis('', y_data)
    # through list
    # dimensiondata
    scatter.set_global_opts(visualmap_opts=[opts.VisualMapOpts(is_show=True, type_='size', dimension=2, pos_top='10%'),
                                            opts.VisualMapOpts(is_show=True, type_='color', dimension=3, pos_top='40%'),
                                            opts.VisualMapOpts(is_show=True, type_='opacity', dimension=4,
                                                               # VisualMapOptrange_opacity，need to 
                                                               range_opacity=[0.2, 1], pos_top='70%')],
                            xaxis_opts=opts.AxisOpts(type_="value"))
    return scatter


chart = scatter_with_visualmap_color_size_opacity()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e22e0b6908804200ab68a3eeba0095c0" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e22e0b6908804200ab68a3eeba0095c0 = echarts.init(
#                     document.getElementById('e22e0b6908804200ab68a3eeba0095c0'), 'light', {renderer: 'canvas'});
#                 var option_e22e0b6908804200ab68a3eeba0095c0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     96,
#                     47,
#                     15,
#                     75,
#                     100
#                 ],
#                 [
#                     90,
#                     34,
#                     40,
#                     46,
#                     97
#                 ],
#                 [
#                     29,
#                     37,
#                     78,
#                     14,
#                     90
#                 ],
#                 [
#                     10,
#                     83,
#                     17,
#                     49,
#                     29
#                 ],
#                 [
#                     99,
#                     49,
#                     96,
#                     48,
#                     96
#                 ],
#                 [
#                     10,
#                     41,
#                     90,
#                     3,
#                     59
#                 ],
#                 [
#                     62,
#                     17,
#                     45,
#                     7,
#                     77
#                 ],
#                 [
#                     28,
#                     58,
#                     20,
#                     22,
#                     17
#                 ],
#                 [
#                     100,
#                     26,
#                     43,
#                     30,
#                     22
#                 ],
#                 [
#                     36,
#                     72,
#                     4,
#                     74,
#                     60
#                 ],
#                 [
#                     66,
#                     20,
#                     26,
#                     64,
#                     35
#                 ],
#                 [
#                     49,
#                     49,
#                     7,
#                     83,
#                     46
#                 ],
#                 [
#                     70,
#                     48,
#                     88,
#                     73,
#                     44
#                 ],
#                 [
#                     76,
#                     0,
#                     77,
#                     70,
#                     40
#                 ],
#                 [
#                     87,
#                     64,
#                     47,
#                     10,
#                     5
#                 ],
#                 [
#                     66,
#                     46,
#                     90,
#                     81,
#                     37
#                 ],
#                 [
#                     97,
#                     18,
#                     64,
#                     63,
#                     18
#                 ],
#                 [
#                     2,
#                     29,
#                     7,
#                     39,
#                     88
#                 ],
#                 [
#                     30,
#                     100,
#                     37,
#                     49,
#                     39
#                 ],
#                 [
#                     14,
#                     79,
#                     25,
#                     92,
#                     90
#                 ],
#                 [
#                     27,
#                     32,
#                     59,
#                     42,
#                     62
#                 ],
#                 [
#                     40,
#                     65,
#                     18,
#                     75,
#                     16
#                 ],
#                 [
#                     12,
#                     54,
#                     24,
#                     70,
#                     18
#                 ],
#                 [
#                     19,
#                     56,
#                     45,
#                     55,
#                     67
#                 ],
#                 [
#                     10,
#                     88,
#                     3,
#                     15,
#                     14
#                 ],
#                 [
#                     95,
#                     85,
#                     4,
#                     46,
#                     68
#                 ],
#                 [
#                     36,
#                     61,
#                     81,
#                     83,
#                     4
#                 ],
#                 [
#                     3,
#                     69,
#                     9,
#                     37,
#                     52
#                 ],
#                 [
#                     21,
#                     73,
#                     79,
#                     47,
#                     86
#                 ],
#                 [
#                     4,
#                     37,
#                     59,
#                     82,
#                     54
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 96,
#                 90,
#                 29,
#                 10,
#                 99,
#                 10,
#                 62,

# %% [markdown]
# #### 45.Color

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random


x_data = [random.randint(0, 100) for _ in range(30)]
y_data = [(random.randint(0, 100), random.randint(0, 100), random.randint(0, 100)) for _ in range(30)]


def scatter_with_custom_bgColor():
    scatter = Scatter(
        init_opts=opts.InitOpts(theme='light',
                                width='1000px',
                                height='600px',
                                # Color
                                bg_color='#008B8B'))
    scatter.add_xaxis(x_data)
    scatter.add_yaxis('', y_data)
    # through list
    # dimensiondata
    scatter.set_global_opts(visualmap_opts=[opts.VisualMapOpts(is_show=True, type_='size', dimension=2),
                                            opts.VisualMapOpts(is_show=True, type_='color', dimension=3)],
                            xaxis_opts=opts.AxisOpts(type_="value"))
    return scatter


chart = scatter_with_custom_bgColor()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9af538b2e26948749c86311416590644" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9af538b2e26948749c86311416590644 = echarts.init(
#                     document.getElementById('9af538b2e26948749c86311416590644'), 'light', {renderer: 'canvas'});
#                 var option_9af538b2e26948749c86311416590644 = {
#     "backgroundColor": "#008B8B",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     93,
#                     25,
#                     80,
#                     84
#                 ],
#                 [
#                     65,
#                     5,
#                     97,
#                     24
#                 ],
#                 [
#                     73,
#                     97,
#                     8,
#                     81
#                 ],
#                 [
#                     97,
#                     70,
#                     60,
#                     68
#                 ],
#                 [
#                     9,
#                     91,
#                     61,
#                     49
#                 ],
#                 [
#                     37,
#                     0,
#                     81,
#                     47
#                 ],
#                 [
#                     81,
#                     89,
#                     63,
#                     90
#                 ],
#                 [
#                     90,
#                     12,
#                     77,
#                     5
#                 ],
#                 [
#                     6,
#                     1,
#                     38,
#                     86
#                 ],
#                 [
#                     54,
#                     38,
#                     98,
#                     78
#                 ],
#                 [
#                     30,
#                     40,
#                     23,
#                     21
#                 ],
#                 [
#                     89,
#                     24,
#                     60,
#                     63
#                 ],
#                 [
#                     29,
#                     43,
#                     77,
#                     43
#                 ],
#                 [
#                     16,
#                     31,
#                     41,
#                     13
#                 ],
#                 [
#                     37,
#                     19,
#                     7,
#                     37
#                 ],
#                 [
#                     92,
#                     87,
#                     9,
#                     20
#                 ],
#                 [
#                     85,
#                     18,
#                     19,
#                     2
#                 ],
#                 [
#                     27,
#                     23,
#                     61,
#                     23
#                 ],
#                 [
#                     39,
#                     81,
#                     4,
#                     73
#                 ],
#                 [
#                     4,
#                     5,
#                     39,
#                     30
#                 ],
#                 [
#                     29,
#                     88,
#                     59,
#                     34
#                 ],
#                 [
#                     84,
#                     44,
#                     56,
#                     95
#                 ],
#                 [
#                     27,
#                     43,
#                     13,
#                     47
#                 ],
#                 [
#                     32,
#                     63,
#                     34,
#                     50
#                 ],
#                 [
#                     59,
#                     54,
#                     55,
#                     73
#                 ],
#                 [
#                     93,
#                     20,
#                     8,
#                     63
#                 ],
#                 [
#                     69,
#                     38,
#                     93,
#                     81
#                 ],
#                 [
#                     68,
#                     12,
#                     85,
#                     14
#                 ],
#                 [
#                     42,
#                     70,
#                     67,
#                     26
#                 ],
#                 [
#                     15,
#                     56,
#                     48,
#                     14
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 93,
#                 65,
#                 73,
#                 97,
#                 9,
#                 37,
#                 81,
#                 90,
#                 6,
#                 54,
#                 30,
#                 89,
#                 29,
#                 16,
#                 37,
#                 92,
#                 85,
#                 27,
#                 39,
#                 4,
#                 29,
#                 84,
#                 27,
#                 32,
#                 59,
#                 93,
#                 69,
#                 68,
#                 42,
#                 15
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "o

# %% [markdown]
# #### 46.Word Cloud

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

text = """
I used to rule the world
Seas would rise when I gave the word
Now in the morning I sleep alone
Sweep the streets I used to own
I used to roll the dice
Feel the fear in my enemy eyes
Listen as the crowd would sing
Now the old king is dead
Long live the king
One minute I held the key
Next the walls were closed on me
And I discovered that my castles stand
Upon pillars of salt and pillars of sand
I hear Jerusalem bells are ringing
Roman Cavalry choirs are singing
Be my mirror my sword and shield
My missionaries in a foreign field
For some reason I can't explain
Once you go there was never
Never an honest word
That was when I ruled the world
"""

word_list = set(text.split(' '))

words = [(word, random.randint(1, 100)) for word in word_list]


def wordcloud_custom_word_size():
    wordcloud = WordCloud(init_opts=opts.InitOpts(theme='light',
                                                  width='1000px',
                                                  height='600px'))
    wordcloud.add('',
                  words,
                  # 
                  word_size_range=[10, 50])

    return wordcloud


chart = wordcloud_custom_word_size()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="4534410293224b888008e5b7a397f0d2" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_4534410293224b888008e5b7a397f0d2 = echarts.init(
#                     document.getElementById('4534410293224b888008e5b7a397f0d2'), 'light', {renderer: 'canvas'});
#                 var option_4534410293224b888008e5b7a397f0d2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 10,
#                 50
#             ],
#             "data": [
#                 {
#                     "name": "go",
#                     "value": 43,
#                     "textStyle": {
#                         "color": "rgb(94,94,81)"
#                     }
#                 },
#                 {
#                     "name": "bells",
#                     "value": 81,
#                     "textStyle": {
#                         "color": "rgb(92,54,116)"
#                     }
#                 },
#                 {
#                     "name": "dead\nLong",
#                     "value": 85,
#                     "textStyle": {
#                         "color": "rgb(24,144,132)"
#                     }
#                 },
#                 {
#                     "name": "were",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(5,70,56)"
#                     }
#                 },
#                 {
#                     "name": "world\n",
#                     "value": 19,
#                     "textStyle": {
#                         "color": "rgb(134,151,18)"
#                     }
#                 },
#                 {
#                     "name": "you",
#                     "value": 95,
#                     "textStyle": {
#                         "color": "rgb(79,119,103)"
#                     }
#                 },
#                 {
#                     "name": "streets",
#                     "value": 87,
#                     "textStyle": {
#                         "color": "rgb(69,107,18)"
#                     }
#                 },
#                 {
#                     "name": "alone\nSweep",
#                     "value": 80,
#                     "textStyle": {
#                         "color": "rgb(65,87,114)"
#                     }
#                 },
#                 {
#                     "name": "pillars",
#                     "value": 68,
#                     "textStyle": {
#                         "color": "rgb(32,27,82)"
#                     }
#                 },
#                 {
#                     "name": "walls",
#                     "value": 43,
#                     "textStyle": {
#                         "color": "rgb(7,138,48)"
#                     }
#                 },
#                 {
#                     "name": "honest",
#                     "value": 35,
#                     "textStyle": {
#                         "color": "rgb(156,97,80)"
#                     }
#                 },
#                 {
#                     "name": "sleep",
#                     "value": 2,
#                     "textStyle": {
#                         "color": "rgb(43,123,84)"
#                     }
#                 },
#                 {
#                     "name": "singing\nBe",
#                     "value": 64,
#                     "textStyle": {
#                         "color": "rgb(91,140,141)"
#                     }
#                 },
#                 {
#                     "name": "sing\nNow",
#                     "value": 23,
#                     "textStyle": {
#                         "color": "rgb(132,2,119)"
#                     }
#                 },
#                 {
#                     "name": "shield\nMy",
#                     "value": 90,
#                     "textStyle": {
#                         "color": "rgb(87,7,128)"
#                     }
#                 },
#                 {
#                     "name": "would",
#                     "value": 3,
#                     "textStyle": {
#                         "color": "rgb(36,126,25)"
#                     }
#                 },
#                 {
#                     "name": "explain\nOnce",
#                     "value": 85,
#                     "textStyle": {
#                         "color": "rgb(58,116,136)"
#                     }
#                 },
#                 {
#                     "name": "roll",
#                     "value": 83,
#                     "textStyle": {
#                         "color": "rgb(150,103,6)"
#                     }
#                 },
#                 {
#                     "name": "rule",
#                     "value": 50,
#                     "textStyle": {
#                         "color": "rgb(41,128,38)"
#                     }
#                 },
#                 {
#                     "name": "me\nAnd",
#                     "value": 17,
#                     "textStyle": {
#                         "color": "rgb(99,60,0)"
#                     }
#                 },
#                 {
#                     "name": "gave",
#                     "value": 47,
#                     "textStyle": {
#                         "color": "rgb(151,125,24)"
#                     }
#                 },
#                 {
#                     "name": "dice\nFeel",
#                     "value": 79,
#                     "textStyle": {
#                         "color": "rgb(34,139,99)"
#                     }
#                 },
#                 {
#                     "name": "and",
#                     "value": 73,
#                     "textStyle": {
#                         "color": "rgb(74,53,153)"
#                     }
#                 },
#                 {
#                     "name": "mirror",
#                     "value": 31,
#                     "textStyle": {
#                         "color": "rgb(148,42,104)"
#                     }
#                 },
#                 {
#                     "name": "when",
#                     "value": 31,
#                     "textStyle": {
#                         "color": "rgb(82,127,91)"
#                     }
#                 },
#                 {
#                     "name": "is",
#                     "value": 72,
#                     "textStyle": {
#                         "color": "rgb(85,96,9)"
#                     }
#                 },
#                 {
#                     "name": "key\nNext",
#                     "value": 23,
#                     "textStyle": {
#                         "color": "rgb(43,8,150)"
#                     }
#                 },
#                 {
#                     "name": "discovered",
#                     "value": 11,
#                     "textStyle": {
#                         "color": "rgb(85,82,130)"
#                     }
#                 },
#                 {
#                     "name": "stand\nUpon",
#                     "value": 69,
#                     "textStyle": {
#                         "color": "rgb(36,78,85)"
#                     }
#                 },
#                 {
#                     "name": "morning",
#                     "value": 22,
#                     "textStyle": {
#                         "color": "rgb(17,112,55)"
#                     }
#                 },
#                 {
#                     "name": "was",
#                     "value": 50,
#                     "textStyle": {
#                         "color": "rgb(4,48,95)"
#                     }
#                 },
#                 {

# %% [markdown]
# #### 47.Map

# %%
from pyecharts.charts import *
from pyecharts import options as opts

data = [('', 10430),
        ('', 9579),
        ('', 9402),
        ('', 8041),
        ('', 7866),
        ('', 7185),
        ('', 6568),
        ('', 5950),
        ('', 5724),
        ('', 5442),
        ('', 4603),
        ('', 4597),
        ('', 4457),
        ('', 4375),
        ('', 3831),
        ('', 3733),
        ('', 3571),
        ('', 3552),
        ('', 3477),
        ('', 2884),
        ('', 2746),
        ('', 2557),
        ('', 2471),
        ('', 2316),
        ('', 2301),
        ('', 2181),
        ('', 1961),
        ('days', 1294),
        ('', 867),
        ('', 710),
        ('', 630),
        ('', 562),
        ('', 300),
        ('', 55)]


def map_with_viusalmap():
    map_chart = Map(init_opts=opts.InitOpts(theme='light',
                                            width='1000px',
                                            height='600px'))
    map_chart.add('Population（）',
                  data_pair=data,
                  maptype='china',
                  # symbol
                  is_map_symbol_show=False)

    map_chart.set_global_opts(visualmap_opts=opts.VisualMapOpts(
        max_=10430,  # visualmapdata【0，100】，
        is_piecewise=True,
        range_color=["#CCD3D9", "#E6B6C2", "#D4587A", "#DC364C"]
    ))
    return map_chart


chart = map_with_viusalmap()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="c555cd3c0ce243598d857680122a947f" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_c555cd3c0ce243598d857680122a947f = echarts.init(
#                     document.getElementById('c555cd3c0ce243598d857680122a947f'), 'light', {renderer: 'canvas'});
#                 var option_c555cd3c0ce243598d857680122a947f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "map",
#             "name": "\u4eba\u53e3\uff08\u4e07\u4eba\uff09",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "map": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 10430
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 9579
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 9402
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 8041
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 7866
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 7185
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 6568
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 5950
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 5724
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 5442
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 4603
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 4597
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 4457
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 4375
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 3831
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 3733
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 3571
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 3552
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 3477
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 2884
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 2746
#                 },
#                 {
#                     "name": "\u7518\u8083\u7701",
#                     "value": 2557
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 2471
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 2316
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 2301
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 2181
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 1961
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 1294
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 867
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 710
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 630
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 562
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 300
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 55
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": false,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4eba\u53e3\uff08\u4e07\u4eba\uff09"
#             ],
#             "selected": {
#                 "\u4eba\u53e3\uff08\u4e07\u4eba\uff09": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 10430,
#         "inRange": {
#             "color": [
#                 "#CCD3D9",
#                 "#E6B6C2",
#                 "#D4587A",
#                 "#DC364C"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     }
# };
#                 chart_c555cd3c0ce243598d857680122a947f.setOption(option_c555cd3c0ce243598d857680122a947f);
#         });
#     </script>

# %% [markdown]
# #### 48.Page

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def page_simple_layout():
    # 1
    bar_1 = Bar(init_opts=opts.InitOpts(theme='light',
                                        width='500px',
                                        height='300px'))
    bar_1.add_xaxis(Faker.choose())
    bar_1.add_yaxis('A', Faker.values())
    bar_1.add_yaxis('B', Faker.values())

    # 2
    bar_2 = Bar(init_opts=opts.InitOpts(theme='light',
                                        width='500px',
                                        height='300px'))
    bar_2.add_xaxis(Faker.choose())
    bar_2.add_yaxis('A', Faker.values())
    # x,y
    bar_2.reversal_axis()

    # 3
    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='500px',
                                        height='300px'))
    line.add_xaxis(Faker.choose())
    line.add_yaxis('A', Faker.values())
    line.add_yaxis('B', Faker.values())

    # 4
    pie = Pie(init_opts=opts.InitOpts(theme='light',
                                      width='500px',
                                      height='300px'))
    pie.add("",
            [list(z) for z in zip(Faker.choose(), Faker.values())],
            radius=["40%", "75%"])

    page = Page(layout=Page.SimplePageLayout)
    # need to  chart  height/width， because different 
    page.add(bar_1, bar_2, line, pie)

    return page


chart = page_simple_layout()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c1a09067fd9945ac9e5fefd92469e47f" style="width:500px; height:300px;"></div>
#         <div id="ef75a945414e463abf1725e71b726e0e" style="width:500px; height:300px;"></div>
#         <div id="7396b7bcd8ef43cf86842ea999e066fb" style="width:500px; height:300px;"></div>
#         <div id="c8c2265dc3d9414dbf78d78d15f4a221" style="width:500px; height:300px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c1a09067fd9945ac9e5fefd92469e47f = echarts.init(
#                     document.getElementById('c1a09067fd9945ac9e5fefd92469e47f'), 'light', {renderer: 'canvas'});
#                 var option_c1a09067fd9945ac9e5fefd92469e47f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "legendHoverLink": true,
#             "data": [
#                 44,
#                 89,
#                 59,
#                 106,
#                 102,
#                 62,
#                 56
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "B",
#             "legendHoverLink": true,
#             "data": [
#                 112,
#                 124,
#                 146,
#                 49,
#                 70,
#                 63,
#                 74
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u767e\u5a01",
#                 "\u9752\u5c9b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_c1a09067fd9945ac9e5fefd92469e47f.setOption(option_c1a09067fd9945ac9e5fefd92469e47f);
#                 var chart_ef75a945414e463abf1725e71b726e0e = echarts.init(
#                     document.getElementById('ef75a945414e463abf1725e71b726e0e'), 'light', {renderer: 'canvas'});
#                 var option_ef75a945414e463abf1725e71b726e0e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "legendHoverLink": true,
#             "data": [
#                 50,
#                 39,
#                 132,
#                 34,
#                 135,
#                 133,
#                 130
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A"
#             ],
#             "selected": {
#                 "A": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,

# %% [markdown]
# #### 49.Tab
#
# * through Grid，GridTab；

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def tab_with_multiple_chart():
    # 1
    bar = Bar()
    bar.add_xaxis(Faker.choose())
    bar.add_yaxis("A", Faker.values())
    bar.add_yaxis("B", Faker.values())

    # 2
    line = Line()
    line.add_xaxis(Faker.choose())
    line.add_yaxis("A", Faker.values())
    line.add_yaxis("B", Faker.values())

    # through Grid1 and 2
    grid = Grid()
    grid.add(bar, grid_opts=opts.GridOpts(pos_bottom="60%"))
    grid.add(line, grid_opts=opts.GridOpts(pos_top="60%"))

    # GridTab
    tab = Tab()
    tab.add(grid, '')

    return tab


chart = tab_with_multiple_chart()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#     <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: block;
#         }
#
#         .chart-container:nth-child(n+2) {
#             display: none;
#         }
#     </style>
# <div class="tab">
#             <button class="tablinks" onclick="showChart(event, 'bff3fe35229d41509128ac970ca19fc4')"></button>
#     </div>
#
#         <div id="bff3fe35229d41509128ac970ca19fc4" class="chart-container" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bff3fe35229d41509128ac970ca19fc4 = echarts.init(
#                     document.getElementById('bff3fe35229d41509128ac970ca19fc4'), 'white', {renderer: 'canvas'});
#                 var option_bff3fe35229d41509128ac970ca19fc4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 76,
#                 123,
#                 133,
#                 80,
#                 82,
#                 30,
#                 44
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 139,
#                 76,
#                 144,
#                 69,
#                 142,
#                 29,
#                 85
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     71
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     144
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     141
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     23
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     123
#                 ],
#                 [
#                     "VIVO",
#                     148
#                 ],
#                 [
#                     "OPPO",
#                     74
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     58
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     99
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     112
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     138
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     113
#                 ],
#                 [
#                     "VIVO",
#                     108
#                 ],
#                 [
#                     "OPPO",
#                     74
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             }
#         },
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumbe

# %% [markdown]
# #### 50.Timeline

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def timeline_auto_play():
    timeline = Timeline(init_opts=opts.InitOpts(theme='light',
                                                width='1000px',
                                                height='600px'))
    timeline.add_schema(is_auto_play=True,  # 
                        is_loop_play=True  # 
                        )
    for year in range(2000, 2020):
        bar = Bar()
        bar.add_xaxis(['', '', '', '', '', '', ''])
        bar.add_yaxis('A', Faker.values())
        bar.add_yaxis('B', Faker.values())
        timeline.add(bar, '{}year'.format(year))
    return timeline


chart = timeline_auto_play()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4c79ad2aa61647e9ad10521689cbaab2" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4c79ad2aa61647e9ad10521689cbaab2 = echarts.init(
#                     document.getElementById('4c79ad2aa61647e9ad10521689cbaab2'), 'light', {renderer: 'canvas'});
#                 var option_4c79ad2aa61647e9ad10521689cbaab2 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "A",
#                 "legendHoverLink": true,
#                 "data": [
#                     145,
#                     85,
#                     23,
#                     29,
#                     113,
#                     137,
#                     54
#                 ],
#                 "realtimeSort": false,
#                 "showBackground": false,
#                 "stackStrategy": "samesign",
#                 "cursor": "pointer",
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             },
#             {
#                 "type": "bar",
#                 "name": "B",
#                 "legendHoverLink": true,
#                 "data": [
#                     142,
#                     46,
#                     20,
#                     114,
#                     129,
#                     119,
#                     44
#                 ],
#                 "realtimeSort": false,
#                 "showBackground": false,
#                 "stackStrategy": "samesign",
#                 "cursor": "pointer",
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "currentIndex": 0,
#             "orient": "horizontal",
#             "autoPlay": true,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "progress": {},
#             "data": [
#                 "2000\u5e74",
#                 "2001\u5e74",
#                 "2002\u5e74",
#                 "2003\u5e74",
#                 "2004\u5e74",
#                 "2005\u5e74",
#                 "2006\u5e74",
#                 "2007\u5e74",
#                 "2008\u5e74",
#                 "2009\u5e74",
#                 "2010\u5e74",
#                 "2011\u5e74",
#                 "2012\u5e74",
#                 "2013\u5e74",
#                 "2014\u5e74",
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74",
#                 "2019\u5e74"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": true,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u9999\u8549",
#                     "\u68a8\u5b50",
#                     "\u6c34\u871c\u6843",
#                     "\u6838\u6843",
#                     "\u897f\u74dc",
#                     "\u82f9\u679c",
#                     "\u83e0\u841d"
#                 ]
#             }
#         ],
#         "yAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": true,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 }
#             }
#         ]
#     },
#     "options": [
#         {
#             "legend": [
#                 {
#                     "data": [
#                         "A",
#                         "B"
#                     ],
#                     "selected": {
#                         "A": true,
#                         "B": true
#                     }
#                 }
#             ],
#             "series": [
#                 {
#                     "type": "bar",
#                     "name": "A",
#                     "legendHoverLink": true,
#                     "data": [
#                         58,
#                         81,
#                         41,
#                         67,
#                         96,
#                         106,
#                         129
#                     ],
#                     "realtimeSort": false,
#                     "showBackground": false,
#                     "stackStrategy": "samesign",
#                     "cursor": "pointer",
#                     "barMinHeight": 0,
#                     "barCategoryGap": "20%",
#                     "barGap": "30%",
#                     "large": false,
#                     "largeThreshold": 400,
#                     "seriesLayoutBy": "column",
#                     "datasetIndex": 0,
#                     "clip": true,
#                     "zlevel": 0,
#                     "z": 2,
#                     "label": {
#                         "show": true,
#                         "margin": 8
#                     }
#                 },
#                 {
#                     "type": "bar",
#                     "name": "B",
#                     "legendHoverLink": true,
#                     "data": [
#                         90,
#                         61,
#                         125,
#                         54,
#                         66,
#                         93,
#                         112
#                     ],
#                     "realtimeSort": false,
#                     "showBackground": false,
#                     "stackStrategy": "samesign",
#                     "cursor": "pointer",
#                     "barMinHeight": 0,
#                     "barCategoryGap": "20%",
#                     "barGap": "30%",
#                     "large": false,
#                     "largeThreshold": 400,
#                     "seriesLayoutBy": "column",
#                     "datasetIndex": 0,
#                     "clip": true,
#                     "zlevel": 0,
#                     "z": 2,
#                     "label": {
#                         "show": true,
#                         "margin": 8
#                     }
#                 }
#             ],
#             "xAxis": [
#                 {
#                     "show": true,
#                     "scale": false,
#                     "nameLocation": "end",
#                     "nameGap": 15,
#                     "gridIndex": 0,
